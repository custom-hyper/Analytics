# %% [markdown]
# <a href="https://colab.research.google.com/github/custom-hyper/Analytics/blob/main/2023-02-06%E2%80%93FIL-----Trading_Report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
CoinGecko_id = "filecoin" #@param {type:"string"}
yahoo_id = "FIL-USD" #@param {type:"string"}

# %% [markdown]
# Archive:

# %% [markdown]
# # Highlights
#
#
# ### Big Picture: **Bullish**
#
# * Macroeconomic data is positive
#
# * Fear and greed index  moved up significantly
# * VIX going down
# * S&P, QQQ, all breaking out
# * Prices are becoming extended after 2 strong weeks
#
# Entry: consolidation area
# Exit:  Consolidation breakdown
#
# ### Token/Stock Selection
#
#
#
# Selection Types
#
# - [ ] Leader / Lagger
# - [ ] Major news
# - [ ] Pump and dump
#
#
# Criteria
#
# - [ ] Not too choppy / clean price action
# - [ ] Strong narrative/fundamentals with likely follow-through
# - [ ] Leader or Lagger
# - [ ] Fits with my long-term thematic research
# - [ ] Elevated ATR
# - [ ] Momentum follows indices/sector
# - [ ] Recent sentiment in line with trade
# - [ ] No specific eventlikely to steal the show (i.e.critical economic announcements)
# - [ ] Elevated volume( i.e. 2 times average volume)
# - [ ] Multiweek consolidation
#
#
# Score: 7.5/10
#
# ### Technical Analysis
#
# Back
#
#
# Important levels:
# Trend:
#
# Score: at
# Trade  Strategy
#
#
#
# Setup
#
# - [ ] Channel
# - [ ] Breakout/breakdown
# - [ ] Gap up/down
# - [ ] Cup and  handle
#
#
#
# What I'm watching
#
# - [ ] Funding rate
# - [ ] Sector
# - [ ] Overall market
# - [ ] Key Levels (Ranked 7/10 min)
# - [ ] Twitter
# - [ ] Economic calendar
#
# Entry:
# - [ ] Risk reward > 5 before major resistance
# - [ X ] Momentum with volume in the same direction
# - [ ] Ongoing Breakout/Breakdown
# - [ X ] Heavy volume as we break
# - [ ] Moved less than 1 ATR
# - [ ] Favorable Overall Market Direction
# - [ ] Accelerating Tape (not mandatory)
#
# Stop:
# - [ ] Opposite end of the breakout candlestick
# - [ ] Trail on 20, 50 day moving average based on fundamentals/narrative follow through
#
# Exit:
# - [ ] After 3-5d run, cover 30-5
# - [ ] Cover if you hit moving average resistance (right now the 50 day)
# - [ ] Trail the rest on a moving average
# - [ ] Likely conflicting economic announcements? Putting tight stop/Take profit
# - [ ] Major random event|(earnings, economic) take profit if no edge
# - [ ] Fundamental do not have follow-through based on research
# - [ ] Weekly catalyst not going your way
# - [ ] Facing tough resistance
# - [ ] Oversold
# - [ ] Greed
#
#
#
#
#
# Score:
#
# ---
#
# ### Tape Reading /Research
#
#
# Recording:
#
# Score:
#
# ---
#
# ### Trade Management
#
#
#
# Performance
#
# - [ ] Emotions
# - [ ] Respected Buying/selling rules
# - [ ] Attractive Risk/Reward update
# - [ ] Fundamentals Follow-through
# - [ ] Adverse news
# - [ ] Elevated Volume
# - [ ] Responsible stoploss
# - [ ] Low Funding Rate
# - [ ] Support/Resistance
# - [ ] Focus
#
#
#  where  was your initial stop? Did you change your stop is the tray developed? Why
#   below 2200 day moving average
#
#  Where would you add size?
#
# Where did you take profits? How do you pick profit targets?
#
# Score:
#
# ---
#
# ### Technology
#
#
# Charting:
# - Tradingview
#
# Alerts:
# - Tradingview
#
# Scanner:
# - Binance
# - FTX
# - CoinGecko API
#
# News:
# - Trading Economics
#
# Macro
# - Blockworks Macro
#
# Research
# - Reddit
# - Bankless
# - Empire
# - Coin Bureau
# - Delphi Digital
# Currently Building Infrastructure: Journaling Playbook System
#
# Score:

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
#@title
# !pip install statistics --quiet
# !pip install yfinance --quiet
# !pip install pytrends --quiet
# !pip install pycoingecko --quiet
# !pip install pandas --quiet
# !pip install Backtesting --quiet
# !pip install mplfinance --quiet
# !pip install configparser --quiet
# !pip install psycopg2-binary==2.8.6 --quiet
# !pip install tweepy==4.10.1 --quiet


# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb 
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
# !dpkg -i libta.deb ta.deb 
# !pip install ta-lib --quiet
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (Reading database ... 129522 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) over (0.4.0-oneiric1) ...
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) over (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...

# %%
#@title Import Project  Dependencies { display-mode: "code" }
import requests
import mplfinance as fplt
from datetime import datetime as dt
from datetime import timedelta
from datetime import date
import talib as ta
import time
import json
import seaborn as sns
from google.colab import data_table
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import logging
import sys
from tqdm.notebook import tqdm
import os
import sqlite3 as sq
import psycopg2 as pg
import configparser
from sqlalchemy import create_engine
from pycoingecko import CoinGeckoAPI
import numpy as np
#from __future__ import division

# %% [markdown]
# Highlights

# %%
#@title Set up SQLite { display-mode: "code" }
#@title  Connect { display-mode: "code" }
path = '/content/drive/MyDrive/workspace/pipelines/db/' #@param {type: 'string'
database = "db.sqlite" #@param {type: 'string'
conn_SQLite = sq.connect(path+database)

# %% [markdown]
# # Big  Picture

# %%
#@title
#@title Google Trends
import seaborn as sns
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(10, 5))
# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()


pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title
#@title Crypto Fear & Greed Index

import requests

from datetime import datetime
import time
import json
from google.colab import data_table
import numpy as np
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt



#General Information table
response = requests.get("https://api.alternative.me/fng/?limit=0")
output = response.text
json_parsed = json.loads(output)

df = pd.json_normalize(json_parsed)


df1 = pd.concat([pd.json_normalize(x) for x in df['data'].values.tolist()])
timeseries = df1['timestamp']
df1['date'] = pd.to_datetime(df1['timestamp'], unit = 's')

df_fear_greed = pd.concat([df1['date'], df1['value']], axis=1)
df3 = pd.concat([df1['date'], df1['value_classification']])

# %%
#@title
#@title


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

plt.style.use("dark_background")
#sns.set_theme(style="darkgrid")

#Choose the date range
df_fear_greed = df_fear_greed[(df_fear_greed['date'] > '2016-04-01')]

df_fear_greed['value'] = df_fear_greed['value'].astype(int)
 
plt.figure(figsize=(20, 5))

sns.lineplot(data=df_fear_greed, linewidth=2.5, x="date", y="value", sort=False)
#sns.lineplot(df_fear_greed=df, linewidth=2.5, x="date", y="TotalCapMrktCurUSD")
plt.title('Crypto Fear & Greed Index Score')

plt.xticks(rotation=45)

plt.legend()


df_fear_greed.head(1)


import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

df_fear_greed['daily_ret'] = df_fear_greed['value'].pct_change(1)

ECDF = sns.displot(df_fear_greed, x="daily_ret", kind="ecdf")

Histogram = df_fear_greed['daily_ret'].hist(bins = 50)


plt.title('Daily Return %')

plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %% [markdown]
# # Technical Analysis

# %%
#@title S&P 500
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
import talib as ta

ticker='SPY'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['longName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")

# %%
#@title  VIX
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='^VIX'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['shortName']

data = yf.download(tickers=ticker, period='200d')
print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['Close'].hist(bins = 50,figsize = (7,5))
sns.displot(data, x="daily_ret", kind="ecdf")


plt.title('Daily Return %')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – ^VIX
#
# – Stock Market News for Feb 6, 2023
# – Stock Market News for Feb 3, 2023
# – Stock Market News for Feb 2, 2023
# – Stock Market News for Feb 1, 2023
# – Hawkish Fed could hobble volatility funds’ stock buying spree
# – Stock Market News for Jan 31, 2023
# – UPDATE 1-JPMorgan reviews oversight of traders amid boom in financial markets - sources
# /usr/local/lib/python3.8/dist-packages/mplfinance/plotting.py:694: UserWarning:
#
# Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
# Text(0.5, 1.0, 'Daily Return %')

# %%
#@title

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )


data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))
sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# /usr/local/lib/python3.8/dist-packages/mplfinance/plotting.py:694: UserWarning:
#
# Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.

# %%
#@title Bitcoin
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='BTC-USD'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['shortName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass
  
fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )
data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")

data['daily_ret'].hist(bins = 50,figsize = (7,5))
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – BTC-USD

# %%
#@title Ethereum
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='ETH-USD'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['shortName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

  
fplt.plot(
            data,
            type='candle',
            style='mike',
            title =Name,
            ylabel='Price ($)',
            volume=True,
            mav = (10,20,50,100,200),
            ylabel_lower='Volume',
            )

data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")

data['daily_ret'].hist(bins = 50,figsize = (7,5))
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – ETH-USD
#
# – Bitwarden Boosts FIDO Alliance Membership
# – Kemin Bio Solutions Launches FermSAVER™ for Use in Ethanol Production
# – PlanetArt Launches First-of-Its-Kind ChatGPT Technology Integration with Its Ink Cards App
# – Pinecone now available on AWS Marketplace and GCP Marketplace
# – Volt Inu (VOLT) Already Making Crazy Returns Before The Bull Run
# – Veterinary Diagnostics Market  Size to Reach USD 17.25 Billion in 2030 | Emergen Research
# – Acticor Biotech Announces the Appointment of Patricia Zilliox to the Board of Directors as an Independent Director

# %%
#@title Correlation

import numpy as np 
import pandas as pd 
# Used to grab the stock prices, with yahoo 
import pandas_datareader as web 
from datetime import datetime 
# To visualize the results 
import matplotlib.pyplot as plt 
import seaborn

start = datetime(2022,9, 1)
symbols_list = [yahoo_id,'SPY', 'QQQ', 'ETH-USD', 'BTC-USD', 'TLT', 'DXY', 'GLD']
#array to store prices
symbols=[]

#array to store prices
symbols=[]
for ticker in symbols_list:     
    
    r = yf.download(tickers=ticker, period='200d')
    # add a symbol column   
    r['Symbol'] = ticker    
    symbols.append(r)
# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
df.head()
df_pivot=df.pivot('Date','Symbol','Close').reset_index()
df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DXY: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Crypto

# %% [markdown]
# Trade Management

# %%
#@title Fundamentals

import requests
import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()

  
response = requests.get("https://api.coingecko.com/api/v3/coins/{}".format(CoinGecko_id))
output = response.text
json_parsed = json.loads(output)


x = json_parsed['market_data']['fully_diluted_valuation']

def fdv_none_val(x):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if x is None :
    fully_diluted_valuation = 0
  else :
    fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']
  
  return fully_diluted_valuation



def zero_div(x,y):
  """
  handling 0 division error
    
  """
  try:
      return x/y
  except ZeroDivisionError:
      return 0
links = 'Complete list: '+str(json_parsed['links'])
chat_url = 'Chat: '+str(json_parsed['links']['chat_url'])
CoinGecko_Link =  'CoinGecko: '+ "https://www.coingecko.com/en/coins/" + CoinGecko_id
Twitters = 'Twitter: '+str('https://twitter.com/')+str(json_parsed['links']['twitter_screen_name'])
homepage = 'Homepage: '+str(json_parsed['links']['homepage'])
subreddit_url =  'Reddit: ' +str(json_parsed['links']['subreddit_url'])
pd.set_option('display.width', 10)

print('')
print('WEB Links')
print('')
print(homepage)
print(Twitters)
print(subreddit_url)
print(chat_url)
print(CoinGecko_Link)

print(links)

print('')  
print('MARKET DATA')  
print('')  


market_cap = json_parsed['market_data']['market_cap']['usd']
circulating_supply = json_parsed['market_data']['circulating_supply']
# circulating_supply.astype(int) 
current_price = json_parsed['market_data']['current_price']['usd']
# current_price.astype(int) 
fdv_to_tvl_rati = json_parsed['market_data']['fdv_to_tvl_ratio']
# fdv_to_tvl_ratio.astype(int) 


#fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']['usd']

# fully_diluted_valuation
total_supply = json_parsed['market_data']['total_supply']
max_supply = json_parsed['market_data']['max_supply']
mcap_to_tvl_ratio = json_parsed['market_data']['mcap_to_tvl_ratio']
total_supply = json_parsed['market_data']['total_supply']
#total_value_locked = json_parsed['market_data']['total_value_locked']['usd']
total_volume = json_parsed['market_data']['total_volume']['usd']

float_rotation_24h = zero_div(total_volume , market_cap)
circulating_cap = current_price * json_parsed['market_data']['circulating_supply']
total_cap = current_price * total_supply


def max_cap(current_price, max_supply):
  """
    Calculation of maximum capitalization 
     Requiring current price and maximum supply
  """
  if max_supply is not None :
    max_cap = current_price * max_supply
  else :
    max_cap = 0
  return max_cap

max_cap = max_cap(current_price, max_supply)



def max_supply_expansion_multiple(circulating_supply, max_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if max_supply is None :
    max_supply_expansion_multiple = 0
    
  elif circulating_supply ==  0:
    max_supply_expansion_multiple == 0
  
  else :
    max_supply_expansion_multiple = max_supply  / circulating_supply
  
  return max_supply_expansion_multiple


max_supply_expansion_multiple = max_supply_expansion_multiple(circulating_supply, max_supply)

def total_supply_expansion_multiple(circulating_supply, total_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if total_supply is None :
    total_supply_expansion_multiple = 0
    
  elif circulating_supply == 0:
    total_supply_expansion_multiple == 0
  
  else :
    total_supply_expansion_multiple = total_supply  / circulating_supply
  
  return total_supply_expansion_multiple


"""
def market_cap_dilution_ratio(fully_diluted_valuation, market_cap):


  if fully_diluted_valuation or market_cap is None :
    market_cap_dilution_ratio == 0
    
  elif fully_diluted_valuation or market_cap is 0:
    market_cap_dilution_ratio == 0

  elif fully_diluted_valuation or market_cap is {}:
    market_cap_dilution_ratio == 0

  else :
    market_cap_dilution_ratio =  fully_diluted_valuation / market_cap
  
  return market_cap_dilution_ratio


market_cap_dilution_ratio = market_cap_dilution_ratio(fully_diluted_valuation, market_cap)
"""

print('')  

circulating_versus_max = circulating_supply/total_supply
dict_custom = {}
#dict_custom['total_supply_expansion_multiple'] = total_supply_expansionWhere_multiple
dict_custom['max_supply_expansion_multiple'] = max_supply_expansion_multiple
dict_custom['float_rotation_24h'] = float_rotation_24h

dict_custom['circulating_versus_max'] = circulating_versus_max


print(dict_custom)

df_market = {}
df_market['market_cap'] = market_cap
#Final been up what is on the national emergency, informative or what basket is something the P is the spaciousness up to Sarah  ankedat1['circulating_supply'] = circulating_supply
df_market['current_price'] = current_price
# df_market['fdv_to_tvl_ratio'] = fdv_to_tvl_ratio#
#df_market['fully_diluted_valuation'] = fully_diluted_valuation
# ankedat1['max_supply'] = max_supply
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_supply'] = total_supply
#df_market['total_value_locked'] = total_value_locked
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_volume'] = total_volume


print(df_market)




print('          ')  
print('PRICE ACTION')  
price_change_percentage_7d = json_parsed['market_data']['price_change_percentage_7d']
price_change_percentage_14d = json_parsed['market_data']['price_change_percentage_14d']
price_change_percentage_30d = json_parsed['market_data']['price_change_percentage_30d']
price_change_percentage_60d = json_parsed['market_data']['price_change_percentage_60d']
price_change_percentage_200d = json_parsed['market_data']['price_change_percentage_200d']
price_change_percentage_1y = json_parsed['market_data']['price_change_percentage_1y']



dict_return = {}
dict_return['price_change_percentage_7d'] = price_change_percentage_7d
dict_return['price_change_percentage_14d'] = price_change_percentage_14d
dict_return['price_change_percentage_30d'] = price_change_percentage_30d
dict_return['price_change_percentage_60d'] = price_change_percentage_60d
dict_return['price_change_percentage_200d'] = price_change_percentage_200d
dict_return['price_change_percentage_1y'] = price_change_percentage_1y

print(dict_return)



category = json_parsed['categories']

print('')  
print('CATEGORIES')  
print(category)
  



description  = [] 
pd.set_option('display.width', 10)
pd.set_option("display.max_rows", None, "display.max_columns", None)
description = json_parsed['description']['en']

print('')  
print('DESCRIPTION: ')
print(description)


links = json_parsed['links']

print('')  
print('LIQUIDITY: ')
print('')  

a = json_parsed['tickers']
data = pd.json_normalize(a,max_level=4)
df = pd.DataFrame(data)

df['pair'] = df['base'] + df['target'] 

df['market_and_volume'] = df['market.name']+ ' (' + df['volume'].round(1).astype(str)+')'
df['Exchanges'] = df.apply(lambda _: ', '.join(df['market_and_volume'] .tolist()), axis=1)
df['Exchanges'][1]

df
# Out:
# WEB Links
#
# Homepage: ['https://filecoin.io/', '', '']
# Twitter: https://twitter.com/Filecoin
# Reddit: None
# Chat: ['https://filecoinproject.slack.com/join/shared_invite/zt-i1jlpzdj-3d2e2mZgb2laCKIUDelP1w#/', '', '']
# CoinGecko: https://www.coingecko.com/en/coins/filecoin
# Complete list: {'homepage': ['https://filecoin.io/', '', ''], 'blockchain_site': ['https://filfox.info/en', 'https://filscan.io/#/tipset/chain', 'https://hecoinfo.com/token/0xae3a768f9ab104c69a7cd6041fe16ffa235d1810', 'https://explorer.energi.network/token/0xf8a425e39af1976e1826f0c8843149afa5e9ec04', '', '', '', '', '', ''], 'official_forum_url': ['https://filecoin.io/blog/', 'https://discuss.filecoin.io/', ''], 'chat_url': ['https://filecoinproject.slack.com/join/shared_invite/zt-i1jlpzdj-3d2e2mZgb2laCKIUDelP1w#/', '', ''], 'announcement_url': ['https://liftoff.filecoin.io/', ''], 'twitter_screen_name': 'Filecoin', 'facebook_username': '', 'bitcointalk_thread_identifier': None, 'telegram_channel_identifier': '', 'subreddit_url': None, 'repos_url': {'github': ['https://github.com/filecoin-project/'], 'bitbucket': []}}
#
# MARKET DATA
#
#
# {'max_supply_expansion_multiple': 5.1756741396402735, 'float_rotation_24h': 0.0796857798734228, 'circulating_versus_max': 0.1932115455919146}
# {'market_cap': 2017060864, 'current_price': 5.3, 'mcap_to_tvl_ratio': None, 'total_supply': 1965831130.0, 'total_volume': 160731068}
#
# PRICE ACTION
# {'price_change_percentage_7d': -3.71706, 'price_change_percentage_14d': -2.5712, 'price_change_percentage_30d': 58.5547, 'price_change_percentage_60d': 21.79998, 'price_change_percentage_200d': -5.0194, 'price_change_percentage_1y': -75.99984}
#
# CATEGORIES
# ['Infrastructure', 'Storage']
#
# DESCRIPTION:
# The Filecoin network achieves staggering economies of scale by allowing anyone worldwide to participate as storage providers. It also makes storage resemble a commodity or utility by decoupling hard-drive space from additional services. On this robust global market the price of storage will be driven by supply and demand, not corporate pricing departments, and miners will compete on factors like reputation for reliability as well as price.
#
# LIQUIDITY:
#                                           base  \
# 0                                          FIL
# 1                                          FIL
# 2                                          FIL
# 3                                          FIL
# 4                                          FIL
# 5                                          FIL
# 6                                          FIL
# 7                                          FIL
# 8                                          FIL
# 9                                          FIL
# 10                                         FIL
# 11                                         FIL
# 12                                         FIL
# 13                                         FIL
# 14                                         FIL
# 15                                         FIL
# 16                                         FIL
# 17                                         FIL
# 18                                         FIL
# 19                                         FIL
# 20                                         FIL
# 21                                         FIL
# 22                                         FIL
# 23                                         FIL
# 24                                         FIL
# 25                                         FIL
# 26                                         FIL
# 27                                         FIL
# 28                                         FIL
# 29                                         FIL
# 30                                         FIL
# 31                                         FIL
# 32                                         FIL
# 33                                         FIL
# 34                                         FIL
# 35                                         FIL
# 36                                         FIL
# 37                                         FIL
# 38                                         FIL
# 39                                         FIL
# 40                                         FIL
# 41                                         FIL
# 42                                         FIL
# 43                                         FIL
# 44                                         FIL
# 45                                         FIL
# 46                                         FIL
# 47                                         FIL
# 48                                         FIL
# 49                                         FIL
# 50                                         FIL
# 51                                         FIL
# 52                                         FIL
# 53                                         FIL
# 54                                         FIL
# 55                                         FIL
# 56                                         FIL
# 57                                         FIL
# 58                                         FIL
# 59                                         FIL
# 60                                         FIL
# 61                                         FIL
# 62                                         FIL
# 63                                         FIL
# 64  0XF8A425E39AF1976E1826F0C8843149AFA5E9EC04
# 65                                         FIL
# 66                                         FIL
# 67                                         FIL
# 68                                         FIL
# 69                                         FIL
# 70                                         FIL
# 71                                         FIL
# 72                                         FIL
# 73                                         FIL
# 74                                         FIL
# 75                                         FIL
# 76                                         FIL
# 77                                         FIL
# 78                                         FIL
# 79                                         FIL
# 80                                         FIL
# 81                                         FIL
# 82                                         FIL
# 83                                         FIL
# 84                                         FIL
# 85                                         FIL
# 86                                         FIL
# 87                                         FIL
# 88                                         FIL
# 89                                         FIL
# 90                                         FIL
# 91                                         FIL
# 92                                         FIL
# 93                                         FIL
# 94                                         FIL
# 95                                         FIL
# 96                                         FIL
# 97                                         FIL
# 98                                         FIL
# 99                                         FIL
#
#                                         target  \
# 0                                         USDT
# 1                                         USDT
# 2                                         USDT
# 3                                         USDT
# 4                                          USD
# 5                                         USDT
# 6                                         USDT
# 7                                         USDT
# 8                                         USDT
# 9                                         USDT
# 10                                         USD
# 11                                        USDT
# 12                                        BUSD
# 13                                        USDT
# 14                                        BUSD
# 15                                        USDT
# 16                                         BTC
# 17                                         USD
# 18                                         EUR
# 19                                        USDT
# 20                                         BTC
# 21                                         EUR
# 22                                        USDC
# 23                                         BTC
# 24                                        USDT
# 25                                        USDC
# 26                                        USDT
# 27                                        USDT
# 28                                        USDT
# 29                                         BTC
# 30                                         EUR
# 31                                        USDT
# 32                                         GBP
# 33                                         ETH
# 34                                         BTC
# 35                                        USDT
# 36                                        USDT
# 37                                        USDT
# 38                                         BTC
# 39                                         BTC
# 40                                         USD
# 41                                        USDT
# 42                                         USD
# 43                                        USDT
# 44                                         ETH
# 45                                         BNB
# 46                                        USDT
# 47                                        USDT
# 48                                        USDT
# 49                                         BTC
# 50                                        USDC
# 51                                        USDC
# 52                                        USDT
# 53                                         ETH
# 54                                        BUSD
# 55                                         BTC
# 56                                        USDT
# 57                                        USDD
# 58                                        USDT
# 59                                         ETH
# 60                                         ETH
# 61                                         BTC
# 62                                        USDC
# 63                                        USDT
# 64  0XA55F26319462355474A9F2C8790860776A329AA4
# 65                                        USDT
# 66                                        USDT
# 67                                        USDT
# 68                                        USDT
# 69                                         USD
# 70                                        USDT
# 71                                        USDT
# 72                                        USDT
# 73                                        USDT
# 74                                        USDT
# 33  5.474650e+03
# 34  1.717784e+04
# 35  4.688870e+05
# 36  1.056589e+04
# 37  8.477866e+03
# 38  6.771815e+03
# 39  7.707235e+03
# 40  1.183636e+04
# 41  7.349360e+04
# 42  4.384467e+03
# 43  2.457581e+03
# 44  3.964311e+04
# 45  3.028678e+04
# 46  5.511588e+05
# 47  1.074469e+04
# 48  1.836813e+04
# 49  3.114166e+04
# 50  4.796007e+03
# 51  1.062247e+04
# 52  4.998730e+04
# 53  9.914898e+03
# 54  1.880844e+05
# 55  3.128447e+03
# 56  1.153931e+04
# 57  3.946582e+04
# 58  6.225044e+04
# 59  3.309973e+03
# 60  1.147545e+03
# 61  1.104355e+03
# 62  1.182501e+03
# 63  1.016351e+03
# 64  2.306858e+01
# 65  1.403110e+02
# 66  1.096768e+03
# 67  1.355946e+06
# 68  1.355946e+06
# 69  1.386234e+06
# 70  5.519536e+06
# 71  8.915129e+03
# 72  9.663933e+02
# 73  1.028163e+04
# 74  5.216346e+04
# 75  1.370060e+03
# 76  5.111539e+03
# 77  8.518192e+03
# 78  2.324812e+04
# 79  1.794157e+04
# 80  2.934459e+05
# 81  2.628099e+02
# 82  4.175900e+02
# 83  5.081838e+02
# 84  1.465949e+02
# 85  3.033529e+04
# 86  1.236908e+04
# 87  3.022900e+03
# 88  3.552421e+04
# 89  1.288050e+01
# 90  1.796568e+01
# 91  1.282053e+04
# 92  1.288888e+04
# 93  6.047726e+03
# 94  2.121930e+01
# 95  3.128703e+03
# 96  4.005347e+04
# 97  1.101180e+03
# 98  1.538442e+05
# 99  1.986371e+03
#
#    trust_score  \
# 0        green
# 1        green
# 2        green
# 3        green
# 4        green
# 5        green
# 6        green
# 7        green
# 8        green
# 9        green
# 10       green
# 11       green
# 12       green
# 13       green
# 14       green
# 15       green
# 16       green
# 17       green
# 18       green
# 19       green
# 20       green
# 21       green
# 22       green
# 23       green
# 24       green
# 25       green
# 26       green
# 27       green
# 28       green
# 29       green
# 30       green
# 31       green
# 32       green
# 33       green
# 34       green
# 35       green
# 36       green
# 37       green
# 38       green
# 39       green
# 40       green
# 41       green
# 42       green
# 43       green
# 44       green
# 45       green
# 46       green
# 47       green
# 48       green
# 49       green
# 50       green
# 51       green
# 52       green
# 53       green
# 54       green
# 55       green
# 56       green
# 57       green
# 58       green
# 59       green
# 60       green
# 61       green
# 62       green
# 63       green
# 64       green
# 65       green
# 66       green
# 67      yellow
# 68      yellow
# 69      yellow
# 70      yellow
# 71      yellow
# 72      yellow
# 73      yellow
# 74      yellow
# 75      yellow
# 76      yellow
# 77      yellow
# 78      yellow
# 79      yellow
# 80      yellow
# 81      yellow
# 82      yellow
# 83      yellow
# 84      yellow
# 85      yellow
# 86      yellow
# 87      yellow
# 88      yellow
# 89      yellow
# 90      yellow
# 91         red
# 92         red
# 93         red
# 94         red
# 95         red
# 96        None
# 97        None
# 98        None
# 99        None
#
#     bid_ask_spread_percentage  \
# 0                    0.022587
# 1                    0.011887
# 2                    0.413845
# 3                    0.018832
# 4                    0.056370
# 5                    0.018857
# 6                    0.075472
# 7                    0.060342
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
#
#                                             trade_url  \
# 0                      https://gate.io/trade/FIL_USDT
# 1      https://www.digifinex.com/en-ww/trade/USDT/FIL
# 2                https://bingx.com/en-us/spot/FILUSDT
# 3             https://www.okx.com/trade-spot/fil-usdt
# 4              https://pro.coinbase.com/trade/FIL-USD
# 5   https://www.binance.com/en/trade/FIL_USDT?ref=...
# 6         https://www.bitget.com/en/spot/FILUSDT_SPBL
# 7               https://www.bkex.com/#/trade/FIL_USDT
# 8      https://www.deepcoin.com/en/Spot?currentId=FIL
# 9           https://www.bitforex.com/en/spot/fil_usdt
# 10           https://pro.kraken.com/app/trade/FIL-USD
# 11    https://crypto.com/exchange/trade/spot/FIL_USDT
# 12  https://www.binance.com/en/trade/FIL_BUSD?ref=...
# 13   https://www.bibox.com/en/exchange/basic/FIL_USDT
# 14           https://www.tokocrypto.com/trade/FILBUSD
# 15             https://www.mexc.com/exchange/FIL_USDT
# 16      https://www.digifinex.com/en-ww/trade/BTC/FIL
# 17                  https://www.bitfinex.com/t/FILUSD
# 18           https://pro.kraken.com/app/trade/FIL-EUR
# 19  https://www.bitmart.com/trade/en?layout=basic&...
# 20  https://www.binance.com/en/trade/FIL_BTC?ref=3...
# 21             https://pro.coinbase.com/trade/FIL-EUR
# 22        https://www.bitget.com/en/spot/FILUSDC_SPBL
# 23             https://pro.coinbase.com/trade/FIL-BTC
# 24                  https://www.xt.com/trade/fil_usdt
# 25          https://www.bitforex.com/en/spot/fil_usdc
# 26                  https://www.bitfinex.com/t/FILUST
# 27          https://www.bybit.com/trade/spot/FIL/USDT
# 28              https://www.kucoin.com/trade/FIL-USDT
# 29             https://www.okx.com/trade-spot/fil-btc
# 30        https://account.bitvavo.com/markets/FIL-EUR
# 31      https://www.huobi.com/en-us/exchange/fil_usdt
# 32             https://pro.coinbase.com/trade/FIL-GBP
# 33                      https://gate.io/trade/FIL_ETH
# 34         https://www.bitget.com/en/spot/FILBTC_SPBL
# 35           https://www.lbank.info/exchange/fil/usdt
# 36                https://whitebit.com/trade/FIL_USDT
# 37              https://phemex.com/spot/trade/FILUSDT
# 38                      https://gate.io/trade/FIL_BTC
# 39                 https://whitebit.com/trade/FIL_BTC
# 40             https://pro.coinlist.co/trader/FIL-USD
# 41     https://www.hotbit.io/exchange?symbol=FIL_USDT
# 42           https://www.binance.us/trade/pro/FIL_USD
# 43          https://www.binance.us/trade/pro/FIL_USDT
# 44         https://www.bitget.com/en/spot/FILETH_SPBL
# 45  https://www.binance.com/en/trade/FIL_BNB?ref=3...
# 46                     https://big.one/trade/FIL-USDT
# 47  https://www.coinex.com/trading?currency=USDT&d...
# 48  https://ascendex.com/en/cashtrade-spottrading/...
# 49      https://www.hotbit.io/exchange?symbol=FIL_BTC
# 50            https://www.okx.com/trade-spot/fil-usdc
# 51          https://www.bybit.com/trade/spot/FIL/USDC
# 52              https://www.bitrue.com/trade/fil_usdt
# 53  https://www.binance.com/en/trade/FIL_ETH?ref=3...
# 54              https://www.bitrue.com/trade/fil_busd
# 55       https://www.huobi.com/en-us/exchange/fil_btc
# 56        https://pro.btcturk.com/pro/al-sat/FIL_USDT
# 57      https://www.huobi.com/en-us/exchange/fil_usdd
# 58        https://www.fameex.com/en-US/trade/fil-usdt
# 59           https://pro.kraken.com/app/trade/FIL-ETH
# 60       https://www.huobi.com/en-us/exchange/fil_eth
# 61  https://www.coinex.com/trading?currency=BTC&de...
# 62  https://www.coinex.com/trading?currency=USDC&d...
# 63             https://poloniex.com/exchange#fil_usdt
# 64  https://app.energiswap.exchange/#/swap?inputCu...
# 65  https://bittrex.com/Market/Index?MarketName=US...
# 66  https://www.bithumb.pro/en-us/spot/trade?q=FIL...
# 67                     https://hitbtc.com/FIL-to-USDT
# 68                        https://fmfw.io/FIL-to-USDT
# 69            https://www.btse.com/en/trading/FIL-USD
# 70                  https://coindcx.com/trade/FILUSDT
# 71             https://nominex.io/en/markets/FIL/USDT
# 72           https://www.tokocrypto.com/trade/FILUSDT
# 73                         https://x.woo.network/spot
# 74       https://www.pionex.com/en/trade/FIL_USDT/Bot
# 75                   https://www.xt.com/trade/fil_btc
# 76                                               None
# 77             https://www.mexc.com/exchange/FIL_USDC
# 78                  https://bilaxy.com/trade/FIL_USDT
# 79         https://www.cointr.com/en-us/spot/FIL_USDT
# 80                   https://coindcx.com/trade/FILBTC
# 81              https://nominex.io/en/markets/FIL/BTC
# 82     https://crypto.com/exchange/trade/spot/FIL_USD
# 83            https://pro.coinlist.co/trader/FIL-USDT
# 84              https://nominex.io/en/markets/FIL/BNB
# 85                   https://coindcx.com/trade/FILBNB
# 86            https://trade.citex.co.kr/trade/FIL_BTC
# 87            https://coinzix.com/spot/trading/FILBTC
# 88           https://coinzix.com/spot/trading/FILUSDT
# 89  https://www.novadax.com/product/orderbook?pair...
# 90           https://pro.kraken.com/app/trade/FIL-AUD
# 91                      https://hitbtc.com/FIL-to-BTC
# 92                         https://fmfw.io/FIL-to-BTC
# 93    https://www.biconomy.com/exchange?coin=FIL_USDT
# 94                           https://trade.zipmex.com
# 95                 https://oceanex.pro/trades/filusdt
# 96  https://www.binance.com/en/trade/FIL_TRY?ref=3...
# 97           https://pro.kraken.com/app/trade/FIL-XBT
# 98             https://www.bit.com/spot?pair=FIL-USDT
# 99   https://www.huobi.co.kr/en-US/exchange/fil_usdt/
#
#    token_info_url  \
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# 5            None
# 6            None
# 7            None
# 8            None
# 9            None
# 10           None
# 11           None
# 12           None
# 13           None
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           None
# 20           None
# 21           None
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27           None
# 28           None
# 29           None
# 30           None
# 31           None
# 32           None
# 33           None
# 34           None
# 35           None
# 36           None
# 37           None
# 38           None
# 39           None
# 40           None
# 41           None
# 42           None
# 43           None
# 44           None
# 45           None
# 46           None
# 47           None
# 48           None
# 49           None
# 50           None
# 51           None
# 52           None
# 53           None
# 54           None
# 55           None
# 56           None
# 57           None
# 58           None
# 59           None
# 60           None
# 61           None
# 62           None
# 63           None
# 64           None
# 65           None
# 66           None
# 67           None
# 68           None
# 69           None
# 70           None
# 71           None
# 72           None
# 73           None
# 74           None
# 75           None
# 76           None
# 77           None
# 78           None
# 79           None
# 80           None
# 81           None
# 82           None
# 83           None
# 84           None
# 85           None
# 86           None
# 87           None
# 88           None
# 89           None
# 90           None
# 91           None
# 92           None
# 93           None
# 94           None
# 95           None
# 96           None
# 97           None
# 98           None
# 99           None
#
#      coin_id  \
# 0   filecoin
# 1   filecoin
# 2   filecoin
# 3   filecoin
# 4   filecoin
# 5   filecoin
# 6   filecoin
# 7   filecoin
# 8   filecoin
# 9   filecoin
# 10  filecoin
# 11  filecoin
# 12  filecoin
# 13  filecoin
# 14  filecoin
# 15  filecoin
# 16  filecoin
# 17  filecoin
# 18  filecoin
# 19  filecoin
# 20  filecoin
# 21  filecoin
# 22  filecoin
# 23  filecoin
# 24  filecoin
# 25  filecoin
# 26  filecoin
# 27  filecoin
# 28  filecoin
# 29  filecoin
# 30  filecoin
# 31  filecoin
# 32  filecoin
# 33  filecoin
# 34  filecoin
# 35  filecoin
# 36  filecoin
# 37  filecoin
# 38  filecoin
# 39  filecoin
# 40  filecoin
# 41  filecoin
# 42  filecoin
# 43  filecoin
# 44  filecoin
# 45  filecoin
# 46  filecoin
# 47  filecoin
# 48  filecoin
# 49  filecoin
# 50  filecoin
# 51  filecoin
# 52  filecoin
# 53  filecoin
# 54  filecoin
# 55  filecoin
# 56  filecoin
# 57  filecoin
# 58  filecoin
# 59  filecoin
# 60  filecoin
# 61  filecoin
# 62  filecoin
# 63  filecoin
# 64  filecoin
# 65  filecoin
# 66  filecoin
# 67  filecoin
# 68  filecoin
# 69  filecoin
# 70  filecoin
# 71  filecoin
# 72  filecoin
# 73  filecoin
# 74  filecoin
# 75  filecoin
# 76  filecoin
# 77  filecoin
# 78  filecoin
# 79  filecoin
# 80  filecoin
# 81  filecoin
# 82  filecoin
# 83  filecoin
# 84  filecoin
# 85  filecoin
# 86  filecoin
# 87  filecoin
# 88  filecoin
# 89  filecoin
# 90  filecoin
# 91  filecoin
# 92  filecoin
# 93  filecoin
# 94  filecoin
# 95  filecoin
# 96  filecoin
# 97  filecoin
# 98  filecoin
# 99  filecoin
#
#     target_coin_id  \
# 0           tether
# 1           tether
# 2           tether
# 3           tether
# 4              NaN
# 5           tether
# 6           tether
# 7           tether
# 8           tether
# 9           tether
# 10             NaN
# 11          tether
# 12     binance-usd
# 13          tether
# 14     binance-usd
# 15          tether
# 16         bitcoin
# 17             NaN
# 18             NaN
# 19          tether
# 20         bitcoin
# 21             NaN
# 22        usd-coin
# 23         bitcoin
# 24          tether
# 25        usd-coin
# 26          tether
# 27          tether
# 28          tether
# 29         bitcoin
# 30             NaN
# 31          tether
# 32             NaN
# 33        ethereum
# 34         bitcoin
# 35          tether
# 36          tether
# 37          tether
# 38         bitcoin
# 39         bitcoin
# 40             NaN
# 41          tether
# 42             NaN
# 43          tether
# 44        ethereum
# 45     binancecoin
# 46          tether
# 47          tether
# 48          tether
# 49         bitcoin
# 50        usd-coin
# 51        usd-coin
# 52          tether
# 53        ethereum
# 54     binance-usd
# 55         bitcoin
# 56          tether
# 57            usdd
# 58          tether
# 59        ethereum
# 60        ethereum
# 61         bitcoin
# 62        usd-coin
# 63          tether
# 64  wrapped-energi
# 65          tether
# 66          tether
# 67          tether
# 68          tether
# 69             NaN
# 70          tether
# 71          tether
# 72          tether
# 73          tether
# 74          tether
# 75         bitcoin
# 76             NaN
# 77        usd-coin
# 78          tether
# 79          tether
# 80         bitcoin
# 81         bitcoin
# 82             NaN
# 83          tether
# 84     binancecoin
# 85     binancecoin
# 86         bitcoin
# 87         bitcoin
# 88          tether
# 89             NaN
# 90             NaN
# 91         bitcoin
# 92         bitcoin
# 93          tether
# 94          tether
# 95          tether
# 96             NaN
# 97             NaN
# 98          tether
# 99          tether
#
#             market.name  \
# 0               Gate.io
# 1             DigiFinex
# 2                 BingX
# 3                   OKX
# 4     Coinbase Exchange
# 5               Binance
# 6                Bitget
# 7                  BKEX
# 8              Deepcoin
# 9              Bitforex
# 10               Kraken
# 11  Crypto.com Exchange
# 12              Binance
# 13                Bibox
# 14           TokoCrypto
# 15          MEXC Global
# 16            DigiFinex
# 17             Bitfinex
# 18               Kraken
# 19              BitMart
# 20              Binance
# 21    Coinbase Exchange
# 22               Bitget
# 23    Coinbase Exchange
# 24               XT.COM
# 25             Bitforex
# 26             Bitfinex
# 27                Bybit
# 28               KuCoin
# 29                  OKX
# 30              Bitvavo
# 31                Huobi
# 32    Coinbase Exchange
# 33              Gate.io
# 34               Bitget
# 35                LBank
# 36             WhiteBIT
# 37               Phemex
# 38              Gate.io
# 39             WhiteBIT
# 40             Coinlist
# 41               Hotbit
# 42           Binance US
# 43           Binance US
# 44               Bitget
# 45              Binance
# 46               BigONE
# 47               CoinEx
# 48    AscendEX (BitMax)
# 49               Hotbit
# 50                  OKX
# 51                Bybit
# 52               Bitrue
# 53              Binance
# 54               Bitrue
# 55                Huobi
# 56          BtcTurk PRO
# ...
# 70           29291242.00
# 71              47274.00
# 72               5134.36
# 73              54538.00
# 74             275413.00
# 75               7239.72
# 76              27146.00
# 77              45190.00
# 78             123931.00
# 79              94548.00
# 80            1552790.00
# 81               1393.25
# 82               2208.17
# 83               2705.48
# 84                776.67
# 85             160674.00
# 86              65296.00
# 87              16044.46
# 88             188770.00
# 89                 68.45
# 90                 95.75
# 91              67425.00
# 92              68113.00
# 93              32209.00
# 94                112.97
# 95              16609.50
# 96             213457.00
# 97               5844.66
# 98             815805.00
# 99              10540.29
#
#                                                  pair  \
# 0                                             FILUSDT
# 1                                             FILUSDT
# 2                                             FILUSDT
# 3                                             FILUSDT
# 4                                              FILUSD
# 5                                             FILUSDT
# 6                                             FILUSDT
# 7                                             FILUSDT
# 8                                             FILUSDT
# 9                                             FILUSDT
# 10                                             FILUSD
# 11                                            FILUSDT
# 12                                            FILBUSD
# 13                                            FILUSDT
# 14                                            FILBUSD
# 15                                            FILUSDT
# 16                                             FILBTC
# 17                                             FILUSD
# 18                                             FILEUR
# 19                                            FILUSDT
# 20                                             FILBTC
# 21                                             FILEUR
# 22                                            FILUSDC
# 23                                             FILBTC
# 24                                            FILUSDT
# 25                                            FILUSDC
# 26                                            FILUSDT
# 27                                            FILUSDT
# 28                                            FILUSDT
# 29                                             FILBTC
# 30                                             FILEUR
# 31                                            FILUSDT
# 32                                             FILGBP
# 33                                             FILETH
# 34                                             FILBTC
# 35                                            FILUSDT
# 36                                            FILUSDT
# 37                                            FILUSDT
# 38                                             FILBTC
# 39                                             FILBTC
# 40                                             FILUSD
# 41                                            FILUSDT
# 42                                             FILUSD
# 43                                            FILUSDT
# 44                                             FILETH
# 45                                             FILBNB
# 46                                            FILUSDT
# 47                                            FILUSDT
# 48                                            FILUSDT
# 49                                             FILBTC
# 50                                            FILUSDC
# 51                                            FILUSDC
# 52                                            FILUSDT
# 53                                             FILETH
# 54                                            FILBUSD
# 55                                             FILBTC
# 56                                            FILUSDT
# 57                                            FILUSDD
# 58                                            FILUSDT
# 59                                             FILETH
# 60                                             FILETH
# 61                                             FILBTC
# 62                                            FILUSDC
# 63                                            FILUSDT
# 64  0XF8A425E39AF1976E1826F0C8843149AFA5E9EC040XA5...
# 65                                            FILUSDT
# 66                                            FILUSDT
# 67                                            FILUSDT
# 68                                            FILUSDT
# 69                                             FILUSD
# 70                                            FILUSDT
# 71                                            FILUSDT
# 72                                            FILUSDT
# 73                                            FILUSDT
# 74                                            FILUSDT
# 75                                             FILBTC
# 76                                             FILUSD
# 77                                            FILUSDC
# 78                                            FILUSDT
# 79                                            FILUSDT
# 80                                             FILBTC
# 81                                             FILBTC
# 82                                             FILUSD
# 83                                            FILUSDT
# 84                                             FILBNB
# 85                                             FILBNB
# 86                                             FILBTC
# 87                                             FILBTC
# 88                                            FILUSDT
# 89                                             FILBRL
# 90                                             FILAUD
# 91                                             FILBTC
# 92                                             FILBTC
# 93                                            FILUSDT
# 94                                            FILUSDT
# 95                                            FILUSDT
# 96                                             FILTRY
# 97                                             FILXBT
# 98                                            FILUSDT
# 99                                            FILUSDT
#
#                 market_and_volume  \
# 0             Gate.io (1223355.6)
# 1           DigiFinex (1889333.8)
# 2                BingX (606651.4)
# 3                 OKX (2933617.1)
# 4    Coinbase Exchange (710515.8)
# 5             Binance (5515664.5)
# 6               Bitget (157474.4)
# 7                 BKEX (964946.8)
# 8              Deepcoin (68234.7)
# 9             Bitforex (758520.3)
# 10              Kraken (182685.7)
# 11  Crypto.com Exchange (15981.4)
# 12            Binance (2073738.3)
# 13               Bibox (303461.0)
# 14            TokoCrypto (4218.4)
# 15          MEXC Global (25497.8)
# 16            DigiFinex (33100.8)
# 17             Bitfinex (13649.9)
# 18               Kraken (21661.8)
# 19              BitMart (77046.8)
# 20             Binance (293055.4)
# 21     Coinbase Exchange (5877.5)
# 22               Bitget (23056.8)
# 23     Coinbase Exchange (7512.8)
# 24              XT.COM (324624.5)
# 25            Bitforex (437585.3)
# 26              Bitfinex (9316.3)
# 27               Bybit (133360.1)
# 28              KuCoin (166916.0)
# 29                   OKX (9168.0)
# 30              Bitvavo (24937.6)
# 31               Huobi (294337.5)
# 32     Coinbase Exchange (7993.5)
# 33               Gate.io (5474.6)
# 34               Bitget (17177.8)
# 35               LBank (468887.0)
# 36             WhiteBIT (10565.9)
# 37                Phemex (8477.9)
# 38               Gate.io (6771.8)
# 39              WhiteBIT (7707.2)
# 40             Coinlist (11836.4)
# 41               Hotbit (73493.6)
# 42            Binance US (4384.5)
# 43            Binance US (2457.6)
# 44               Bitget (39643.1)
# 45              Binance (30286.8)
# 46              BigONE (551158.8)
# 47               CoinEx (10744.7)
# 48    AscendEX (BitMax) (18368.1)
# 49               Hotbit (31141.7)
# 50                   OKX (4796.0)
# 51                Bybit (10622.5)
# 52               Bitrue (49987.3)
# 53               Binance (9914.9)
# 54              Bitrue (188084.4)
# 55                 Huobi (3128.4)
# 56          BtcTurk PRO (11539.3)
# 57                Huobi (39465.8)
# 58               Fameex (62250.4)
# 59                Kraken (3310.0)
# 60                 Huobi (1147.5)
# 61                CoinEx (1104.4)
# 62                CoinEx (1182.5)
# 63              Poloniex (1016.4)
# 64              Energiswap (23.1)
# 65                Bittrex (140.3)
# 66             BitGlobal (1096.8)
# 67             HitBTC (1355946.3)
# 68            FMFW.io (1355946.3)
# 69               BTSE (1386234.1)
# 70            CoinDCX (5519535.9)
# 71               Nominex (8915.1)
# 72             TokoCrypto (966.4)
# 73          WOO Network (10281.6)
# 74               Pionex (52163.5)
# 75                XT.COM (1370.1)
# 76                Gemini (5111.5)
# 77           MEXC Global (8518.2)
# 78               Bilaxy (23248.1)
# 79           CoinTR Pro (17941.6)
# 80             CoinDCX (293445.9)
# 81                Nominex (262.8)
# 82    Crypto.com Exchange (417.6)
# 83               Coinlist (508.2)
# 84                Nominex (146.6)
# 85              CoinDCX (30335.3)
# 86                CITEX (12369.1)
# 87               Coinzix (3022.9)
# 88              Coinzix (35524.2)
# 89                 NovaDAX (12.9)
# 90                  Kraken (18.0)
# 91               HitBTC (12820.5)
# 92              FMFW.io (12888.9)
# 93              Biconomy (6047.7)
# 94                  Zipmex (21.2)
# 95               Oceanex (3128.7)
# 96              Binance (40053.5)
# 97                Kraken (1101.2)
# 98                 BIT (153844.2)
# 99           Huobi Korea (1986.4)
#
#                                             Exchanges
# 0   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 1   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 2   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 3   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 4   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 5   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 6   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 7   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 8   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 9   Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 10  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 11  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 12  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 13  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 14  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 15  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 16  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 17  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 18  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 19  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 20  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 21  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 22  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 23  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 24  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 25  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 26  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 27  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 28  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 29  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 30  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 31  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 32  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 33  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 34  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 35  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 36  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 37  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 38  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 39  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 40  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 41  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 42  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 43  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 44  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 45  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 46  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 47  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 48  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 49  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 50  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 51  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 52  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 53  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 54  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 55  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 56  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 57  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 58  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 59  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 60  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
# 61  Gate.io (1223355.6), DigiFinex (1889333.8), Bi...
#
,4.53,4.7,4.75,4.69,4.68,4.63,4.63,4.58,4.61,4.36,4.33,4.27,4.36,4.36,4.3,4.33,4.37,4.37,4.37,4.36,4.37,4.42,4.57,4.73,4.9,4.88,4.88,4.88,4.98,4.95,4.97,5.03,5.19,5.42,5.35,5.43,5.49,5.43,5.27,5.31,5.38,5.38,5.46,5.36,5.28,5.23,4.99,4.93,4.97,5.03,5.04,5.3,5.42,5.46,5.45,5.34,5.32,5.29,5.37,5.27,5.33,5.33,5.23,5.26,5.35,5.4,5.45,5.34,5.24,5.27,5.22,5.28,5.32,5.33,5.36,5.38,5.48,5.41,5.36,5.12,5.12,5.13,4.99,5.1,5.05,5.02,5.05,5.21,5.19,5.23,5.14,5.1,5.14,5.16,5.41,5.69,5.71,5.64,5.66,5.66,5.52,5.48,5.5,5.49,5.52,5.63,5.62,5.62,5.57,5.58,5.6,5.59,5.56,5.46,5.48,5.51,5.21,5.23,5.22,5.29,5.23,5.24,5.22,5.31],"open":[3.31,3.33,3.3,3.36,3.39,3.35,3.38,3.37,3.44,3.55,3.58,3.78,3.85,3.87,3.79,3.73,3.7,3.73,3.76,3.79,3.76,3.7,3.71,3.69,3.57,3.61,3.73,3.79,3.77,3.73,3.7,3.85,3.85,3.88,3.83,3.8,3.83,3.8,4.02,4.32,4.41,4.22,4.3,4.2,4.78,4.66,4.59,4.67,4.91,4.71,4.71,4.72,4.74,4.61,4.57,4.63,4.57,4.53,4.73,4.75,4.72,4.74,4.63,4.68,4.65,4.61,4.54,4.4,4.27,4.36,4.37,4.32,4.33,4.42,4.41,4.4,4.37,4.37,4.42,4.57,4.75,4.9,5.03,4.88,4.88,4.98,4.95,4.97,5.03,5.25,5.46,5.61,5.43,5.58,5.44,5.51,5.32,5.52,5.44,5.49,5.46,5.34,5.29,5.27,4.99,4.97,5.13,5.04,5.3,5.54,5.46,5.49,5.39,5.32,5.29,5.37,5.44,5.33,5.39,5.32,5.26,5.39,5.4,5.45,5.42,5.35,5.28,5.29,5.28,5.39,5.34,5.38,5.41,5.5,5.48,5.42,5.36,5.13,5.16,5.0,5.1,5.09,5.12,5.05,5.21,5.33,5.23,5.25,5.14,5.14,5.22,5.41,5.69,5.72 ...

# %%
#@title Seasonality

# %%
#@title Google Trends
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
keyword = str(CoinGecko_id)
keyword = keyword.replace('-',' ')
pytrend.build_payload(kw_list=[keyword])


interest_over_time_df = pytrend.interest_over_time()
df_Google=interest_over_time_df

#print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( keyword, 'y1', data=df_Google, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )

# %%
#@title  Project Recent Tweets
import configparser
import tweepy

config_file = "/content/drive/MyDrive/workspace/config.ini"
config_obj = configparser.ConfigParser()
config_obj.read(config_file)

Twitter = config_obj["Twitter_API"]

consumer_key = Twitter["consumer_key"]
consumer_secret = Twitter["consumer_secret"]
access_token = Twitter["access_token"]
access_token_secret = Twitter["access_token_secret"]

pd.set_option('display.width', 10)

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

user_name =str(json_parsed['links']['twitter_screen_name'])

def twitter_rept(user_name):
    """
    
    Generating text data of recent tweets

    """
    
    user =  api.user_timeline(screen_name = user_name )

    for tweet in user:
      
        print(tweet.created_at)

        print(tweet.text)

        print("------------------------------------------------------------------") 
        print(Twitters)

    return 
    
twitter_rept(user_name)
# Out:
# 2023-02-02 21:06:01+00:00
# No one likes #fomo. Don't miss episode 3 of #FVMFrames on Thursday, 2/9 at 11:30am ET.
#
# 🗓️  RSVP today and see you… https://t.co/JNF11JooXm
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 19:37:33+00:00
# @ethermiami @IPFS @tweetclarita @MiamiHackWeek @Cointelegraph @anna_shakola Excellent opportunity to learn about IPFS &amp; Filecoin. 👌
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 19:33:55+00:00
# Shoutout to these awesome SPs that are leading in the Golden Retriever competition, so far with 500k+ successful re… https://t.co/Cy8HPJXJTi
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 19:31:43+00:00
# @FilecoinTLDR @MessariCrypto Massive adoption. 📈 🚀 🚀
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 19:25:20+00:00
# @marcjohnson518 @fvmdev The potential impact of @fvmdev is massive.
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 19:11:56+00:00
# @IPFS @AlgoveraA legends @AlgoveraAI
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 15:14:26+00:00
# @SadaivCI @juanbenet @hipiyushhere We're honored to join forces with Sadaiv CI! Huge shoutout to @juanbenet and… https://t.co/BZ8qmNknjT
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-02 14:25:06+00:00
# Lucky Storage, one of our unique Storage Providers, chooses Filecoin because of the technical rigor of the protocol… https://t.co/dhAfyyg0mT
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-01 19:36:44+00:00
# RT @FilecoinTLDR: The State of @Filecoin in Q4 by @MessariCrypto was released. Here's the TL;DR...
#
# 📈 Active deals went up 117% QoQ, and 17…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-01 17:23:46+00:00
# @colinevran Awesome visualization! Filecoin is making a massive impact in the world of data storage. 🔥
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-01 15:22:01+00:00
# @momack28 🚀🚀🚀
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-02-01 15:21:23+00:00
# RT @momack28: Pretty mind-boggling🤯 to see how data storage on Filecoin has exploded📈 in the past year!🔥🔥🔥
#
# How it started:…
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 19:39:55+00:00
# Learn about the latest challenges &amp; opportunities of decentralized storage directly from our team:
#
# @stefaanweb3,… https://t.co/1FJRBkHLEL
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 17:04:50+00:00
# India's blockchain and Web3 sector is growing quickly!
#
# Filecoin's @hipiyushhere connected with the Namaste Web3 i… https://t.co/R1CXHc3M3N
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 14:14:37+00:00
# @coinand_com 🙌
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 14:13:23+00:00
# @Estuary_Tech https://t.co/OiNEMVMLQC is a great place to start. Thanks for sharing!
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 13:15:28+00:00
# @_zondax_ @eventbrite Devs, this is your chance! 🚀
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 12:46:50+00:00
# @Devinspark11 Mornin' 👋
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-31 12:34:25+00:00
# @KlardaOfficial Thanks! 🫡
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin
# 2023-01-30 19:14:17+00:00
# @wenbeamupscotie Learn everything about tokenomics in this @FilecoinTLDR blog post.👇
# https://t.co/UGjLIALMHR
# ------------------------------------------------------------------
# Twitter: https://twitter.com/Filecoin

# %% [markdown]
# # Stocks

# %%
#@title Chart
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
import talib as ta

ticker=yahoo_id




ticker_y.info

data = yf.download(tickers=ticker, period='200d')
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=ticker,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#@title Seasonality

# %% [markdown]
# #Back test
