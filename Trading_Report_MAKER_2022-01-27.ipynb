# %% [markdown]
# <a href="https://colab.research.google.com/github/custom-hyper/Analytics/blob/main/Trading_Report_MAKER_2022-01-27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Highlights
#
#
# Big Picture: **Bullish**
#
# * Macroeconomic data is positive
#
# * Fear and greed index  moved up significantly
# * VIX going down
# * S&P, QQQ, all breaking out
# * Prices are becoming extended after 2 strong weeks
#
# Entry: consolidation area
# Exit:  Consolidation breakdown

# %%
#@title
from google.colab import drive
drive.mount('/content/drive')
#@title
# !pip install statistics --quiet
# !pip install yfinance --quiet
# !pip install pytrends --quiet
# !pip install pycoingecko --quiet
# !pip install pandas --quiet
# !pip install Backtesting --quiet
# !pip install mplfinance --quiet
# !pip install configparser --quiet
# !pip install psycopg2-binary==2.8.6 --quiet
# !pip install tweepy==4.10.1 --quiet


# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/libta-lib0_0.4.0-oneiric1_amd64.deb -qO libta.deb 
# !wget https://launchpad.net/~mario-mariomedina/+archive/ubuntu/talib/+files/ta-lib0-dev_0.4.0-oneiric1_amd64.deb -qO ta.deb
# !dpkg -i libta.deb ta.deb 
# !pip install ta-lib --quiet
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for statistics (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 46.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 KB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.5/175.5 KB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for Backtesting (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 KB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 31.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.6/94.6 KB 3.5 MB/s eta 0:00:00
# Selecting previously unselected package libta-lib0.
# (Reading database ... 129502 files and directories currently installed.)
# Preparing to unpack libta.deb ...
# Unpacking libta-lib0 (0.4.0-oneiric1) ...
# Selecting previously unselected package ta-lib0-dev.
# Preparing to unpack ta.deb ...
# Unpacking ta-lib0-dev (0.4.0-oneiric1) ...
# Setting up libta-lib0 (0.4.0-oneiric1) ...
# Setting up ta-lib0-dev (0.4.0-oneiric1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.0/272.0 KB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for ta-lib (pyproject.toml) ... done

# %%
#@title Import Project  Dependencies { display-mode: "code" }
import requests
import mplfinance as fplt
from datetime import datetime as dt
from datetime import timedelta
from datetime import date
import talib as ta
import time
import json
import seaborn as sns
from google.colab import data_table
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pandas.io.json import json_normalize
import logging
import sys
from tqdm.notebook import tqdm
import os
import sqlite3 as sq
import psycopg2 as pg
import configparser
from sqlalchemy import create_engine
from pycoingecko import CoinGeckoAPI
import numpy as np
#from __future__ import division

# %% [markdown]
# Highlights

# %%
CoinGecko_id = "maker" #@param {type:"string"}
yahoo_id = "MKR-USD" #@param {type:"string"}

# %%
#@title Set up SQLite { display-mode: "code" }
#@title  Connect { display-mode: "code" }
path = '/content/drive/MyDrive/workspace/pipelines/db/' #@param {type: 'string'
database = "db.sqlite" #@param {type: 'string'
conn_SQLite = sq.connect(path+database)

# %% [markdown]
# # Big  Picture

# %%
#@title
#@title Google Trends
import seaborn as sns
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt

sns.set(style="ticks", context="talk")
plt.style.use("dark_background")
plt.figure(figsize=(10, 5))
# Only need to run this once, the rest of requests will use the same session.
pytrend = TrendReq()


pytrend.build_payload(kw_list=['Bitcoin', 'Ethereum','Crypto'])

# Interest Over Time
interest_over_time_df = pytrend.interest_over_time()
df=interest_over_time_df

plt.plot( 'Bitcoin', 'y1', data=df, marker='x', color='green',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Ethereum', 'y2', data=df, marker='x', color='yellow',linestyle='-', linewidth=1,ms=1.5 )
plt.plot( 'Crypto', 'y3', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )

#plt.plot( 'Cosmos Crypto', 'y5', data=df, marker='x', color='red',linestyle='-', linewidth=1,ms=1.5 )
plt.legend()


# title
plt.title('Google Trends', loc='center',pad=10)
# Out:
# Text(0.5, 1.0, 'Google Trends')

# %%
#@title
#@title Crypto Fear & Greed Index

import requests

from datetime import datetime
import time
import json
from google.colab import data_table
import numpy as np
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt



#General Information table
response = requests.get("https://api.alternative.me/fng/?limit=0")
output = response.text
json_parsed = json.loads(output)

df = pd.json_normalize(json_parsed)


df1 = pd.concat([pd.json_normalize(x) for x in df['data'].values.tolist()])
timeseries = df1['timestamp']
df1['date'] = pd.to_datetime(df1['timestamp'], unit = 's')

df_fear_greed = pd.concat([df1['date'], df1['value']], axis=1)
df3 = pd.concat([df1['date'], df1['value_classification']])

# %%
#@title
#@title


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

plt.style.use("dark_background")
#sns.set_theme(style="darkgrid")

#Choose the date range
df_fear_greed = df_fear_greed[(df_fear_greed['date'] > '2022-04-01')]

df_fear_greed['value'] = df_fear_greed['value'].astype(int)
 
plt.figure(figsize=(20, 5))

sns.lineplot(data=df_fear_greed, linewidth=2.5, x="date", y="value", sort=False)
#sns.lineplot(df_fear_greed=df, linewidth=2.5, x="date", y="TotalCapMrktCurUSD")
plt.title('Crypto Fear & Greed Index Score')

plt.xticks(rotation=45)

plt.legend()


df_fear_greed.head(1)


import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

df_fear_greed['daily_ret'] = df_fear_greed['value'].pct_change(1)

ECDF = sns.displot(df_fear_greed, x="daily_ret", kind="ecdf")

Histogram = df_fear_greed['daily_ret'].hist(bins = 50)


plt.title('Daily Return %')

plt.show()
# Out:
# <ipython-input-31-c6f8235c612e>:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# <ipython-input-31-c6f8235c612e>:36: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# # Technical Analysis

# %%
#@title S&P 500
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
import talib as ta

ticker='SPY'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['longName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")

# %%
#@title  NASDAQ
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go
import talib as ta

ticker='QQQ'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['longName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')
#@title
import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))

sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
#@title  VIX
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='^VIX'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['shortName']

data = yf.download(tickers=ticker, period='200d')
print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

import mplfinance as fplt

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )

data['daily_ret'] = data['Close'].pct_change(1)
data['Close'].hist(bins = 50,figsize = (7,5))
sns.displot(data, x="daily_ret", kind="ecdf")


plt.title('Daily Return %')
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – ^VIX
#
# – The S&P 500 is trying to top 4100, and the odds favor that happening by the end of January.
# – Stock Market News for Jan 24, 2023
# – Stock Market News for Jan 23, 2023
# – Here Comes Key Economic Data and a Boatload of Earnings
# – Stock Market News for Jan 20, 2023
# – Profit Pain Is About to Give Another Jolt to Teetering Stocks
# – Market check: S&P 500 sells off, volatility picks up
# /usr/local/lib/python3.8/dist-packages/mplfinance/plotting.py:694: UserWarning:
#
# Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.
# Text(0.5, 1.0, 'Daily Return %')

# %%
#@title

fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )


data['daily_ret'] = data['Close'].pct_change(1)
data['daily_ret'].hist(bins = 50,figsize = (7,5))
sns.displot(data, x="daily_ret", kind="ecdf")
# Out:
# /usr/local/lib/python3.8/dist-packages/mplfinance/plotting.py:694: UserWarning:
#
# Attempting to set identical bottom == top == 0.0 results in singular transformations; automatically expanding.

# %%
#@title Bitcoin
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='BTC-USD'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['shortName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass
  
fplt.plot(
            data,
            type='candle',
            style='mike',
            title=Name,
            ylabel='Price ($)',
            volume=True,
            ylabel_lower='Volume',
            mav = (10,20,50,100,200)
            )
data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")

data['daily_ret'].hist(bins = 50,figsize = (7,5))
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – BTC-USD

# %%
#@title Ethereum
import pandas as pd
import yfinance as yf
import plotly.graph_objects as go

ticker='ETH-USD'


ticker_y = yf.Ticker(ticker)
Name = ticker_y.info['shortName']
ticker_y.info

data = yf.download(tickers=ticker, period='200d')



print('')
print('Related News – ' +ticker)
print('')

try:
  for i in range(1,10):
    print('– ' + ticker_y.news[i]['title'])

except Exception:
  pass

  
fplt.plot(
            data,
            type='candle',
            style='mike',
            title =Name,
            ylabel='Price ($)',
            volume=True,
            mav = (10,20,50,100,200),
            ylabel_lower='Volume',
            )

data['daily_ret'] = data['Close'].pct_change(1)

sns.displot(data, x="daily_ret", kind="ecdf")

data['daily_ret'].hist(bins = 50,figsize = (7,5))
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# Related News – ETH-USD
#
# – Wood's ARK Innovation Fund on pace for best month ever as battered stocks surge
# – Chronic Kidney Disease - Camfil Air Filtration Expert Discusses Disease and PM2.5 in Air Pollution
# – Las Vegas, Nevada DISH Wireless 5G Open RAN Network Benchmark Study 2023: Consistently Inconsistent - On-Again/Off-Again Use of Carrier Aggregation was Problematic
# – Goldman Sachs CEO pay drops 30% after profit falls 48% and share price loses 10% in tough 2022
# – UPDATE 1-Officials from Netherlands, Japan in Washington for chip  talks
# – The Michigan Court of Appeals Reverses Termination of Parental Rights Based on Attorney Lisa Kirsch Satawa’s Testimony About the Standard of Care
# – Oil futures give up early gains; U.S. prices fall below $80 a barrel

# %%
#@title Correlation

import numpy as np 
import pandas as pd 
# Used to grab the stock prices, with yahoo 
import pandas_datareader as web 
from datetime import datetime 
# To visualize the results 
import matplotlib.pyplot as plt 
import seaborn

start = datetime(2022,9, 1)
symbols_list = [yahoo_id,'SPY', 'QQQ', 'ETH-USD', 'BTC-USD', 'TLT', 'DXY', 'GLD']
#array to store prices
symbols=[]

#array to store prices
symbols=[]
for ticker in symbols_list:     
    
    r = yf.download(tickers=ticker, period='200d')
    # add a symbol column   
    r['Symbol'] = ticker    
    symbols.append(r)
# concatenate into df
df = pd.concat(symbols)
df = df.reset_index()
df = df[['Date', 'Close', 'Symbol']]
df.head()
df_pivot=df.pivot('Date','Symbol','Close').reset_index()
df_pivot.head()
corr_df = df_pivot.corr(method='pearson')
#reset symbol as index (rather than 0-X)
corr_df.head().reset_index()
#del corr_df.index.name
corr_df.head(10)
plt.figure(figsize=(13, 8))
seaborn.heatmap(corr_df, annot=True, cmap='RdYlGn')
plt.figure()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DXY: Period '200d' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', '5y', '10y', 'ytd', 'max']
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Intraday Fundamentals

# %% [markdown]
# Connect to screener database

# %% [markdown]
# Trade Management

# %%
#@title Fundamentals

import requests
import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()

  
response = requests.get("https://api.coingecko.com/api/v3/coins/{}".format(CoinGecko_id))
output = response.text
json_parsed = json.loads(output)


x = json_parsed['market_data']['fully_diluted_valuation']

def fdv_none_val(x):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if x is None :
    fully_diluted_valuation = 0
  else :
    fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']
  
  return fully_diluted_valuation



def zero_div(x,y):
  """
  handling 0 division error
    
  """
  try:
      return x/y
  except ZeroDivisionError:
      return 0
links = 'Complete list: '+str(json_parsed['links'])
chat_url = 'Chat: '+str(json_parsed['links']['chat_url'])
CoinGecko_Link =  'CoinGecko: '+ "https://www.coingecko.com/en/coins/" + CoinGecko_id
Twitters = 'Twitter: '+str('https://twitter.com/')+str(json_parsed['links']['twitter_screen_name'])
homepage = 'Homepage: '+str(json_parsed['links']['homepage'])
subreddit_url =  'Reddit: ' +str(json_parsed['links']['subreddit_url'])
pd.set_option('display.width', 10)

print('')
print('WEB Links')
print('')
print(homepage)
print(Twitters)
print(subreddit_url)
print(chat_url)
print(CoinGecko_Link)

print(links)

print('')  
print('MARKET DATA')  
print('')  


market_cap = json_parsed['market_data']['market_cap']['usd']
circulating_supply = json_parsed['market_data']['circulating_supply']
# circulating_supply.astype(int) 
current_price = json_parsed['market_data']['current_price']['usd']
# current_price.astype(int) 
fdv_to_tvl_rati = json_parsed['market_data']['fdv_to_tvl_ratio']
# fdv_to_tvl_ratio.astype(int) 


#fully_diluted_valuation = json_parsed['market_data']['fully_diluted_valuation']['usd']

# fully_diluted_valuation
total_supply = json_parsed['market_data']['total_supply']
max_supply = json_parsed['market_data']['max_supply']
mcap_to_tvl_ratio = json_parsed['market_data']['mcap_to_tvl_ratio']
total_supply = json_parsed['market_data']['total_supply']
#total_value_locked = json_parsed['market_data']['total_value_locked']['usd']
total_volume = json_parsed['market_data']['total_volume']['usd']

float_rotation_24h = zero_div(total_volume , market_cap)
circulating_cap = current_price * json_parsed['market_data']['circulating_supply']
total_cap = current_price * total_supply


def max_cap(current_price, max_supply):
  """
    Calculation of maximum capitalization 
     Requiring current price and maximum supply
  """
  if max_supply is not None :
    max_cap = current_price * max_supply
  else :
    max_cap = 0
  return max_cap

max_cap = max_cap(current_price, max_supply)



def max_supply_expansion_multiple(circulating_supply, max_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if max_supply is None :
    max_supply_expansion_multiple = 0
    
  elif circulating_supply ==  0:
    max_supply_expansion_multiple == 0
  
  else :
    max_supply_expansion_multiple = max_supply  / circulating_supply
  
  return max_supply_expansion_multiple


max_supply_expansion_multiple = max_supply_expansion_multiple(circulating_supply, max_supply)

def total_supply_expansion_multiple(circulating_supply, total_supply):
  """
    Calculating supply expansion multiple
    Requiring maximum supply and circulating supply
  """
  if total_supply is None :
    total_supply_expansion_multiple = 0
    
  elif circulating_supply == 0:
    total_supply_expansion_multiple == 0
  
  else :
    total_supply_expansion_multiple = total_supply  / circulating_supply
  
  return total_supply_expansion_multiple


"""
def market_cap_dilution_ratio(fully_diluted_valuation, market_cap):


  if fully_diluted_valuation or market_cap is None :
    market_cap_dilution_ratio == 0
    
  elif fully_diluted_valuation or market_cap is 0:
    market_cap_dilution_ratio == 0

  elif fully_diluted_valuation or market_cap is {}:
    market_cap_dilution_ratio == 0

  else :
    market_cap_dilution_ratio =  fully_diluted_valuation / market_cap
  
  return market_cap_dilution_ratio


market_cap_dilution_ratio = market_cap_dilution_ratio(fully_diluted_valuation, market_cap)
"""

print('')  

circulating_versus_max = circulating_supply/total_supply
dict_custom = {}
#dict_custom['total_supply_expansion_multiple'] = total_supply_expansionWhere_multiple
dict_custom['max_supply_expansion_multiple'] = max_supply_expansion_multiple
dict_custom['float_rotation_24h'] = float_rotation_24h

dict_custom['circulating_versus_max'] = circulating_versus_max


print(dict_custom)

df_market = {}
df_market['market_cap'] = market_cap
#Final been up what is on the national emergency, informative or what basket is something the P is the spaciousness up to Sarah  ankedat1['circulating_supply'] = circulating_supply
df_market['current_price'] = current_price
# df_market['fdv_to_tvl_ratio'] = fdv_to_tvl_ratio#
#df_market['fully_diluted_valuation'] = fully_diluted_valuation
# ankedat1['max_supply'] = max_supply
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_supply'] = total_supply
#df_market['total_value_locked'] = total_value_locked
df_market['mcap_to_tvl_ratio'] = mcap_to_tvl_ratio
df_market['total_volume'] = total_volume


print(df_market)




print('          ')  
print('PRICE ACTION')  
price_change_percentage_7d = json_parsed['market_data']['price_change_percentage_7d']
price_change_percentage_14d = json_parsed['market_data']['price_change_percentage_14d']
price_change_percentage_30d = json_parsed['market_data']['price_change_percentage_30d']
price_change_percentage_60d = json_parsed['market_data']['price_change_percentage_60d']
price_change_percentage_200d = json_parsed['market_data']['price_change_percentage_200d']
price_change_percentage_1y = json_parsed['market_data']['price_change_percentage_1y']



dict_return = {}
dict_return['price_change_percentage_7d'] = price_change_percentage_7d
dict_return['price_change_percentage_14d'] = price_change_percentage_14d
dict_return['price_change_percentage_30d'] = price_change_percentage_30d
dict_return['price_change_percentage_60d'] = price_change_percentage_60d
dict_return['price_change_percentage_200d'] = price_change_percentage_200d
dict_return['price_change_percentage_1y'] = price_change_percentage_1y

print(dict_return)



category = json_parsed['categories']

print('')  
print('CATEGORIES')  
print(category)
  



description  = [] 
pd.set_option('display.width', 10)
pd.set_option("display.max_rows", None, "display.max_columns", None)
description = json_parsed['description']['en']

print('')  
print('DESCRIPTION: ')
print(description)


links = json_parsed['links']

print('')  
print('LIQUIDITY: ')
print('')  

a = json_parsed['tickers']
data = pd.json_normalize(a,max_level=4)
df = pd.DataFrame(data)

df['pair'] = df['base'] + df['target'] 

df['market_and_volume'] = df['market.name']+ ' (' + df['volume'].round(1).astype(str)+')'
df['Exchanges'] = df.apply(lambda _: ', '.join(df['market_and_volume'] .tolist()), axis=1)
df['Exchanges'][1]

df
# Out:
# WEB Links
#
# Homepage: ['https://makerdao.com/', 'https://blog.makerdao.com/', '']
# Twitter: https://twitter.com/MakerDAO
# Reddit: https://www.reddit.com/r/MakerDAO
# Chat: ['https://discord.com/invite/RBRumCpEDH', '', '']
# CoinGecko: https://www.coingecko.com/en/coins/maker
# Complete list: {'homepage': ['https://makerdao.com/', 'https://blog.makerdao.com/', ''], 'blockchain_site': ['https://etherscan.io/token/0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2', 'https://ethplorer.io/address/0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2', 'https://blockchair.com/ethereum/erc-20/token/0x9f8f72aa9304c8b593d555f12ef6589cc3a579a2', 'https://snowtrace.io/token/0x88128fd4b259552a9a1d457f435a6527aab72d42', 'https://arbiscan.io/token/0x2e9a6df78e42a30712c10a9dc4b1c8656f8f2879', 'https://avascan.info/blockchain/c/address/0x88128fd4b259552a9a1d457f435a6527aab72d42/token', 'https://explorer.energi.network/token/0x050317d93f29d1ba5ff3eac3b8157fd4e345588d', 'https://polygonscan.com/token/0x6f7C932e7684666C9fd1d44527765433e01fF61d', '', ''], 'official_forum_url': ['', '', ''], 'chat_url': ['https://discord.com/invite/RBRumCpEDH', '', ''], 'announcement_url': ['', ''], 'twitter_screen_name': 'MakerDAO', 'facebook_username': '', 'bitcointalk_thread_identifier': None, 'telegram_channel_identifier': '', 'subreddit_url': 'https://www.reddit.com/r/MakerDAO', 'repos_url': {'github': ['https://github.com/makerdao/dai.js'], 'bitbucket': []}}
#
# MARKET DATA
#
#
# {'max_supply_expansion_multiple': 1.11568266537122, 'float_rotation_24h': 0.03550116212507972, 'circulating_versus_max': 0.9219336469721666}
# {'market_cap': 593782900, 'current_price': 659.57, 'mcap_to_tvl_ratio': 0.08, 'total_supply': 977631.036950888, 'total_volume': 21079983}
#
# PRICE ACTION
# {'price_change_percentage_7d': -0.87678, 'price_change_percentage_14d': 0.95605, 'price_change_percentage_30d': 21.96319, 'price_change_percentage_60d': 3.04538, 'price_change_percentage_200d': -29.81441, 'price_change_percentage_1y': -61.44468}
#
# CATEGORIES
# ['Lending/Borrowing', 'Avalanche Ecosystem', 'Polygon Ecosystem', 'Near Protocol Ecosystem', 'Arbitrum Ecosystem', 'Decentralized Finance (DeFi)', 'Governance', 'Ethereum Ecosystem']
#
# DESCRIPTION:
# MKR is a cryptocurrency depicted as a smart contract platform and works alongside the Dai coin and aims to act as a hedge currency that provides traders with a stable alternative to the majority of coins currently available on the market. Maker offers a transparent stablecoin system that is fully inspectable on the Ethereum blockchain. Founded almost three years ago, MakerDao is lead by Rune Christensen, its CEO and founder. Maker’s MKR coin is a recent entrant to the market and is not a well known project. However, after today it will be known by many more people after blowing up 40% and it is one of the coins to rise to prominence during the recent peaks and troughs.
#
# After being developed by the MakerDAO team, Maker Dai officially went live on December 18th, 2017. Dai is a price stable coin that is suitable for payments, savings, or collateral and provides cryptocurrency traders with increased options concerning opening and closing positions. Dai lives completely on the blockchain chain with its stability unmediated by the legal system or trusted counterparties and helps facilitate trading while staying entirely in the world of cryptocurrencies. The concept of a stablecoin is fairly straight forward – it’s a token that has its price or value pegged to a particular fiat currency. A stablecoin is a token (like <a href="https://www.coingecko.com/en/coins/bitcoin">Bitcoin</a> and <a href="https://www.coingecko.com/en/coins/ethereum">Ethereum</a>) that exists on a blockchain, but unlike Bitcoin or Ethereum, Dai has no volatility.
#
# MKR is an ERC-20 token on the Ethereum blockchain and can not be mined. It’s instead created/destroyed in response to DAI price fluctuations in order to keep it hovering around $1 USD. MKR is used to pay transaction fees on the Maker system, and it collateralizes the system. Holding MKR comes with voting rights within Maker’s continuous approval voting system. Bad governance devalues MKR tokens, so MKR holders are incentivized to vote for the good of the entire system. It’s a fully decentralized and democratic structure, then, which is an underutilized USP of blockchain tech.
#
# Value volatility is a relative concept among both cryptos and fiat currencies. The US dollar, for example, was worth 110.748 yen on July 9, 2018. On July 4, 2011, $1 was worth 80.64 yen, and on March 18, 1985, $1 was worth 255.65 yen. These are major differences in exchange rates, and inflation within each country makes each currency worth different values even when compared to themselves. One USD in 1913 is worth the equivalent of $25.41 today, and even $1 in 1993 is worth the equivalent of $1.74 today. Stablecoins don’t negate these basic economic principles of value. Instead, both Tether and Dai have values pegged to the U.S. dollar. This is done to stabilize the price.
#
# LIQUIDITY:
#                                           base  \
# 0                                          MKR
# 1                                          MKR
# 2                                          MKR
# 3                                          MKR
# 4                                          MKR
# 5                                          MKR
# 6                                          MKR
# 7                                          MKR
# 8                                          MKR
# 9                                          MKR
# 10                                         MKR
# 11                                         MKR
# 12                                         MKR
# 13                                         MKR
# 14                                         MKR
# 15                                         MKR
# 16                                         MKR
# 17                                         MKR
# 18                                         MKR
# 19                                         MKR
# 20                                         MKR
# 21                                         MKR
# 22                                         MKR
# 23                                         MKR
# 24                                         MKR
# 25                                         MKR
# 26                                         MKR
# 27                                         MKR
# 28                                         MKR
# 29                                         MKR
# 30                                         MKR
# 31                                         MKR
# 32                                         MKR
# 33                                         MKR
# 34                                         MKR
# 35                                         MKR
# 36                                         MKR
# 37                                         MKR
# 38                                         MKR
# 39                                         MKR
# 40                                         MKR
# 41                                         MKR
# 42                                         MKR
# 43                                         MKR
# 44                                         MKR
# 45  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A2
# 46                                         MKR
# 47                                         MKR
# 48                                         MKR
# 49                                         MKR
# 50                                         MKR
# 51                                         MKR
# 52                                         MKR
# 53                                         MKR
# 54                                         MKR
# 55                                         MKR
# 56                                         MKR
# 57                                         MKR
# 58                                         MKR
# 59                                         MKR
# 60                                         MKR
# 61                                         MKR
# 62                                         MKR
# 63                                         MKR
# 64                                         MKR
# 65                                         MKR
# 66                                         MKR
# 67                                         MKR
# 68                                         MKR
# 69                                         MKR
# 70  0X050317D93F29D1BA5FF3EAC3B8157FD4E345588D
# 71  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A2
# 72                                         MKR
# 73                                         MKR
# 74                                         MKR
# 75                                         MKR
# 76                                         MKR
# 77                                         MKR
# 78                                         MKR
# 79                                         MKR
# 80                                         MKR
# 81                                         MKR
# 82                                         MKR
# 83                                         MKR
# 84                                         MKR
# 85                                         MKR
# 86                                         MKR
# 87  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A2
# 88                                         MKR
# 89                                         MKR
# 90                                         MKR
# 91                                         MKR
# 92                                         MKR
# 93                                         MKR
# 94                                         MKR
# 95                                         MKR
# 96                                         MKR
# 97  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A2
# 98                                         MKR
# 99                                         MKR
#
#                                         target  \
# 0                                         USDT
# 1                                          BTC
# 2                                          ETH
# 3                                          USD
# 4                                         USDT
# 5                                         USDT
# 6                                         USDT
# 7                                         USDT
# 8                                         USDT
# 9                                         USDT
# 10                                         EUR
# 11                                        USDT
# 12                                         USD
# 13                                        USDT
# 14                                        BUSD
# 15                                        USDT
# 16                                        USDT
# 17                                        USDT
# 18                                        USDT
# 19                                         EUR
# 20                                         EUR
# 21                                        USDT
# 22                                         JPY
# 23                                        USDT
# 24                                        USDT
# 25                                         USD
# 26                                        USDT
# 27                                         BTC
# 28                                        USDT
# 29                                        USDT
# 30                                         THB
# 31                                         USD
# 32                                         USD
# 33                                        USDT
# 34                                         BTC
# 35                                        USDT
# 36                                         BTC
# 37                                        USDT
# 38                                        USDT
# 39                                        USDT
# 40                                         INR
# 41                                         BTC
# 42                                        USDT
# 43                                        USDT
# 44                                        USDC
# 45  0XC02AAA39B223FE8D0A0E5C4F27EAD9083C756CC2
# 46                                        USDT
# 47                                        BUSD
# 48                                        USDT
# 49                                        USDT
# 50                                        USDT
# 51                                         BNT
# 52                                         USD
# 53                                        USDC
# 54                                         THB
# 55                                        USDT
# 56                                         BTC
# 57                                         BTC
# 58                                         BTC
# 59                                         BTC
# 60                                        USDT
# 61                                         ETH
# 62                                         BTC
# 63                                         ETH
# 64                                        USDT
# 65                                         PHP
# 66                                         BTC
# 67                                         ETH
# 68                                         USD
# 69                                         DAI
# 70  0XA55F26319462355474A9F2C8790860776A329AA4
# 71  0XC02AAA39B223FE8D0A0E5C4F27EAD9083C756CC2
# 72                                         EUR
# 73                                         USD
# 74                                        USDT
# 75                                        USDT
# 76                                        USDT
# 77                                        USDT
# 78                                        USDT
# 79                                        USDT
# 80                                        USDT
# 81                                        BUSD
# 82                                         ETH
# 83                                         ETH
# 84                                         USD
# 85                                         BTC
# 86                                         BTC
# 87  0XC02AAA39B223FE8D0A0E5C4F27EAD9083C756CC2
# 88                                         BTC
# 89                                         BTC
# 90                                         BTC
# 91                                         BTC
# 92                                         GBP
# 93                                         CAD
# 94                                        USDT
# 95                                        USDT
# 96                                        USDT
# 97                                         ETH
# 98                                        USDT
# 99                                         BTC
#
#             last  \
# 0     660.110000
# 1       0.028546
# 2       0.412578
# 3     659.450000
# 4     660.000000
# 5     660.000000
# 6     660.770000
# 7     660.240000
# 8     659.400000
# 9     659.980000
# 10    607.330000
# 11    660.000000
# 12    660.500000
# 13    661.200000
# 14    659.000000
# 15    659.850000
# 16    660.470000
# 17    660.000000
# 18    660.300000
# 19    613.730000
# 20    605.900000
# 21    660.770000
# 22  85805.000000
# 23    660.410000
# 24    659.000000
# 25    660.770000
# 26    657.150000
# 27      0.028400
# 28    658.840000
# 29    658.570000
# 30  21699.570000
# 31    660.000000
# 32    659.588400
# 33    660.980000
# 34      0.028468
# 35    659.277500
# 36      0.028520
# 37    660.000000
# 38    658.350000
# 39    658.960000
# 40  60991.090000
# 41      0.028470
# 42    659.990000
# 43    660.140000
# 44    661.300000
# 45      0.416569
# 46    658.900000
# 47    662.000000
# 48    660.000000
# 49    663.050000
# 50    659.700000
# 51   1557.889953
# 52    654.530000
# 53    659.590000
# 54  21726.000000
# 55    661.000000
# 56      0.028435
# 57      0.028600
# 58      0.028690
# 59      0.028568
# 60    661.600000
# 61      0.414400
# 62      0.028607
# 63      0.415000
# 64    658.710000
# 65  36065.400000
# 66      0.028470
# 67      0.415000
# 68    661.560000
# 69    656.964350
# 70   3259.735038
# 71      0.416256
# 72    607.438354
# 73    659.951400
# 74    659.000000
# 75    660.000000
# 76    660.000000
# 77    660.300000
# 78    658.446000
# 79    659.698000
# 80    660.300000
# 81    659.000000
# 82      0.413510
# 83      0.413510
# 84    657.000000
# 85      0.028460
# 86      0.028460
# 87      0.414271
# 88      0.028470
# 89      0.028400
# 90      0.028470
# 91      0.028512
# 92    532.900000
# 93    880.000000
# 94    660.100000
# 95    659.400000
# 96    654.300000
# 97      0.413467
# 98    654.000000
# 99      0.028470
#
#          volume  \
# 0    563.049788
# 1     83.371955
# 2    525.000000
# 3   3925.890020
# 4   4046.815368
# 5   1030.174804
# 6   1817.551600
# 7     36.472800
# 8    106.694000
# 9    107.264370
# 10    85.889757
# 11   208.035440
# 12   130.843442
# 13  1571.016200
# 14   468.337306
# 15   975.000000
# 16   278.130850
# 17  1633.206700
# 18   939.181104
# 19    11.679859
# 20    21.149043
# 21   104.000000
# 22   125.857600
# 23   204.580600
# 24   136.220200
# 25   128.202318
# 26    31.000000
# 27   144.663510
# 28   789.146200
# 29    28.540716
# 30     9.764300
# 31    79.683998
# 32    88.470257
# 33    17.304025
# 34    93.540000
# 35   141.911200
# 36    22.956780
# 37   746.081696
# 38    14.226438
# 39    66.615401
# 40   713.390200
# 41    58.090000
# 42    91.681619
# 43     8.512962
# 44   110.465326
# 45     6.329158
# 46    44.571000
# 47   413.404100
# 48  1039.507828
# 49    32.997123
# 50   742.236600
# 51     3.057200
# 52    27.977512
# 53    10.518895
# 54    25.545115
# 55    62.707277
# 56    10.838122
# 57   107.940054
# 58     3.671300
# 59    59.565588
# 60     0.000000
# 61     5.980468
# 62     0.166667
# 63    10.251141
# 64    90.835373
# 65     0.401830
# 66     9.124087
# 67     0.401700
# 68     2.093300
# 69   100.048470
# 70     0.139952
# 71   165.917293
# 72     4.335150
# 73     1.980000
# 74     5.428577
# 75  4045.857196
# 76     3.315850
# 77     3.978980
# 78  1136.889600
# 79  1137.402600
# 80   338.756220
# 81     0.700817
# 82     5.917100
# 83     5.918100
# 84   745.992930
# 85    45.769400
# 86    45.759000
# 87    16.773770
# 88   143.711051
# 89    18.259300
# 90     0.015244
# 91     2.942000
# 92     2.640040
# 93     0.094276
# 94    48.262000
# 95   459.944000
# 96   176.651100
# 97     1.555681
# 98   251.304700
# 99   161.068600
#
#    trust_score  \
# 0        green
# 1        green
# 2        green
# 3        green
# 4        green
# 5        green
# 6        green
# 7        green
# 8        green
# 9        green
# 10       green
# 11       green
# 12       green
# 13       green
# 14       green
# 15       green
# 16       green
# 17       green
# 18       green
# 19       green
# 20       green
# 21       green
# 22       green
# 23       green
# 24       green
# 25       green
# 26       green
# 27       green
# 28       green
# 29       green
# 30       green
# 31       green
# 32       green
# 33       green
# 34       green
# 35       green
# 36       green
# 37       green
# 38       green
# 39       green
# 40       green
# 41       green
# 42       green
# 43       green
# 44       green
# 45       green
# 46       green
# 47       green
# 48       green
# 49       green
# 50       green
# 51       green
# 52       green
# 53       green
# 54       green
# 55       green
# 56       green
# 57       green
# 58       green
# 59       green
# 60       green
# 61       green
# 62       green
# 63       green
# 64       green
# 65       green
# 66       green
# 67       green
# 68       green
# 69       green
# 70       green
# 71      yellow
# 72      yellow
# 73      yellow
# 74      yellow
# 75      yellow
# 76      yellow
# 77      yellow
# 78      yellow
# 79      yellow
# 80      yellow
# 81      yellow
# 82      yellow
# 83      yellow
# 84      yellow
# 85      yellow
# 86      yellow
# 87      yellow
# 88      yellow
# 89      yellow
# 90      yellow
# 91      yellow
# 92      yellow
# 93      yellow
# 94      yellow
# 95      yellow
# 96      yellow
# 97      yellow
# 98      yellow
# 99      yellow
#
#     bid_ask_spread_percentage  \
# 0                    0.019090
# 1                    0.690899
# 2                    1.051918
# 3                    0.030322
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# 68     False
# 69     False
# 70     False
# 71     False
# 72     False
# 73     False
# 74     False
# 75     False
# 76     False
# 77     False
# 78     False
# 79     False
# 80     False
# 81     False
# 82     False
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
#
#                                             trade_url  \
# 0      https://www.digifinex.com/en-ww/trade/USDT/MKR
# 1                   https://exmo.com/en/trade/MKR_BTC
# 2     https://www.bibox.com/en/exchange/basic/MKR_ETH
# 3              https://pro.coinbase.com/trade/MKR-USD
# 4   https://www.binance.com/en/trade/MKR_USDT?ref=...
# 5                 https://azbit.com/exchange/MKR_USDT
# 6         https://www.bitget.com/en/spot/MKRUSDT_SPBL
# 7     https://crypto.com/exchange/trade/spot/MKR_USDT
# 8              https://www.mexc.com/exchange/MKR_USDT
# 9                 https://whitebit.com/trade/MKR_USDT
# 10        https://account.bitvavo.com/markets/MKR-EUR
# 11     https://www.deepcoin.com/en/Spot?currentId=MKR
# 12    https://trade.kraken.com/markets/kraken/mkr/usd
# 13           https://www.lbank.info/exchange/mkr/usdt
# 14  https://www.binance.com/en/trade/MKR_BUSD?ref=...
# 15     https://www.dcoin.com/currencyTrading/MKR_USDT
# 16               https://bingx.com/en-us/spot/MKRUSDT
# 17                  https://www.xt.com/trade/mkr_usdt
# 18            https://www.okx.com/trade-spot/mkr-usdt
# 19          https://www.bitstamp.net/markets/mkr/eur/
# 20    https://trade.kraken.com/markets/kraken/mkr/eur
# 21   https://www.bibox.com/en/exchange/basic/MKR_USDT
# 22               https://bitbank.cc/app/trade/MKR_JPY
# 23              https://www.kucoin.com/trade/MKR-USDT
# 24              https://trade.bitazza.com/gl/exchange
# 25                                               None
# 26                          https://app.deversifi.com
# 27  https://www.binance.com/en/trade/MKR_BTC?ref=3...
# 28              https://phemex.com/spot/trade/MKRUSDT
# 29   https://cryptology.com/app/next/trading/MKR_USDT
# 30              https://trade.bitazza.com/gl/exchange
# 31                  https://www.bitfinex.com/t/MKRUSD
# 32           https://www.binance.us/trade/pro/MKR_USD
# 33          https://www.binance.us/trade/pro/MKR_USDT
# 34  https://www.bitmart.com/trade/en?layout=basic&...
# 35     https://www.hotbit.io/exchange?symbol=MKR_USDT
# 36             https://pro.coinbase.com/trade/MKR-BTC
# 37      https://www.huobi.com/en-us/exchange/mkr_usdt
# 38  https://www.coinex.com/trading?currency=USDT&d...
# 39                     https://gate.io/trade/MKR_USDT
# 40                     https://bitbns.com/trade/#/mkr
# 41                   https://www.xt.com/trade/mkr_btc
# 42              https://latoken.com/exchange/USDT-MKR
# 43                  https://www.bitfinex.com/t/MKRUST
# 44            https://www.okx.com/trade-spot/mkr-usdc
# 45  https://app.sushi.com/swap?inputCurrency=0x9f8...
# 46          https://www.bybit.com/trade/spot/MKR/USDT
# 47              https://www.bitrue.com/trade/mkr_busd
# 48             https://www.bit.com/spot?pair=MKR-USDT
# 49        https://pro.btcturk.com/pro/al-sat/MKR_USDT
# 50           https://www.coinstore.com/#/spot/MKRUSDT
# 51  https://app.bancor.network/trade?inputCurrency...
# 52                                               None
# 53  https://www.coinex.com/trading?currency=USDC&d...
# 54                  https://www.bitkub.com/market/MKR
# 55        https://www.fameex.com/en-US/trade/mkr-usdt
# 56  https://www.coinex.com/trading?currency=BTC&de...
# 57             https://www.okx.com/trade-spot/mkr-btc
# 58               https://www.kucoin.com/trade/MKR-BTC
# 59               https://latoken.com/exchange/BTC-MKR
# 60       https://trade.kanga.exchange/market/MKR-USDT
# 61                      https://gate.io/trade/MKR_ETH
# 62  https://bittrex.com/Market/Index?MarketName=BT...
# 63             https://www.okx.com/trade-spot/mkr-eth
# 64       https://www.probit.com/app/exchange/MKR-USDT
# 65          https://pro.coins.ph/en-ph/trade/MKR/PHP/
# 66        https://www.probit.com/app/exchange/MKR-BTC
# 67               https://www.kucoin.com/trade/MKR-ETH
# 68     https://crypto.com/exchange/trade/spot/MKR_USD
# 69                  https://exmo.com/en/trade/MKR_DAI
# 70  https://app.energiswap.exchange/#/swap?inputCu...
# 71  https://app.uniswap.org/#/swap?inputCurrency=0...
# 72          https://go.coinmetro.com/exchange/mkr-eur
# 73          https://go.coinmetro.com/exchange/mkr-usd
# 74             https://nominex.io/en/markets/MKR/USDT
# 75                  https://coindcx.com/trade/MKRUSDT
# 76           https://www.tokocrypto.com/trade/MKRUSDT
# 77                         https://x.woo.network/spot
# 78                        https://fmfw.io/MKR-to-USDT
# 79                     https://hitbtc.com/MKR-to-USDT
# 80       https://www.pionex.com/en/trade/MKR_USDT/Bot
# 81             https://nominex.io/en/markets/MKR/BUSD
# 82                         https://fmfw.io/MKR-to-ETH
# 83                      https://hitbtc.com/MKR-to-ETH
# 84            https://www.btse.com/en/trading/MKR-USD
# 85                      https://hitbtc.com/MKR-to-BTC
# 86                         https://fmfw.io/MKR-to-BTC
# 87  https://app.uniswap.org/#/swap?inputCurrency=0...
# 88                   https://coindcx.com/trade/MKRBTC
# 89                                               None
# 90              https://nominex.io/en/markets/MKR/BTC
# 91        https://www.pionex.com/en/trade/MKR_BTC/Bot
# 92    https://trade.kraken.com/markets/kraken/mkr/gbp
# 93                  https://bitbuy.ca/en/pro/#MKR-CAD
# 94           https://coinzix.com/spot/trading/MKRUSDT
# 95               https://exmarkets.com/trade/mkr-usdt
# 96                  https://bilaxy.com/trade/MKR_USDT
# 97  https://balancer.exchange/#/swap/ether/0x9f8f7...
# 98   https://omgfin.com/exchange/trade/market/MKRUSDT
# 99    https://omgfin.com/exchange/trade/market/MKRBTC
#
#                                        token_info_url  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                               None
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26                                               None
# 27                                               None
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32                                               None
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
# 40                                               None
# 41                                               None
# 42                                               None
# 43                                               None
# 44                                               None
# 45  https://analytics.sushi.com/tokens/0x9f8f72aa9...
# 46                                               None
# 47                                               None
# 48                                               None
# 49                                               None
# 50                                               None
# 51                                               None
# 52                                               None
# 53                                               None
# 54                                               None
# 55                                               None
# 56                                               None
# 57                                               None
# 58                                               None
# 59                                               None
# 60                                               None
# 61                                               None
# 62                                               None
# 63                                               None
# 64                                               None
# 65                                               None
# 66                                               None
# 67                                               None
# 68                                               None
# 69                                               None
# 70                                               None
# 71                                               None
# 72                                               None
# 73                                               None
# 74                                               None
# 75                                               None
# 76                                               None
# 77                                               None
# 78                                               None
# ...
# 59              39364.00
# 60               1086.76
# 61               3935.42
# 62                110.29
# 63               6741.89
# 64              59821.00
# 65                262.01
# 66               6009.59
# 67                265.54
# 68               1384.84
# 69              65728.00
# 70                 90.83
# 71             109192.00
# 72               2861.35
# 73               1306.70
# 74               3583.15
# 75            2669694.00
# 76               2187.99
# 77               2629.68
# 78             748420.00
# 79             742364.00
# 80             221400.00
# 81                461.58
# 82               3897.33
# 83               3885.81
# 84             490117.00
# 85              30040.00
# 86              30129.00
# 87              11015.76
# 88              94655.00
# 89              11995.76
# 90                 10.05
# 91               1937.88
# 92               1742.54
# 93                 62.33
# 94              31848.00
# 95             303204.00
# 96             115547.00
# 97               1025.64
# 98             164302.00
# 99             106078.00
#
#                                                  pair  \
# 0                                             MKRUSDT
# 1                                              MKRBTC
# 2                                              MKRETH
# 3                                              MKRUSD
# 4                                             MKRUSDT
# 5                                             MKRUSDT
# 6                                             MKRUSDT
# 7                                             MKRUSDT
# 8                                             MKRUSDT
# 9                                             MKRUSDT
# 10                                             MKREUR
# 11                                            MKRUSDT
# 12                                             MKRUSD
# 13                                            MKRUSDT
# 14                                            MKRBUSD
# 15                                            MKRUSDT
# 16                                            MKRUSDT
# 17                                            MKRUSDT
# 18                                            MKRUSDT
# 19                                             MKREUR
# 20                                             MKREUR
# 21                                            MKRUSDT
# 22                                             MKRJPY
# 23                                            MKRUSDT
# 24                                            MKRUSDT
# 25                                             MKRUSD
# 26                                            MKRUSDT
# 27                                             MKRBTC
# 28                                            MKRUSDT
# 29                                            MKRUSDT
# 30                                             MKRTHB
# 31                                             MKRUSD
# 32                                             MKRUSD
# 33                                            MKRUSDT
# 34                                             MKRBTC
# 35                                            MKRUSDT
# 36                                             MKRBTC
# 37                                            MKRUSDT
# 38                                            MKRUSDT
# 39                                            MKRUSDT
# 40                                             MKRINR
# 41                                             MKRBTC
# 42                                            MKRUSDT
# 43                                            MKRUSDT
# 44                                            MKRUSDC
# 45  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A20XC0...
# 46                                            MKRUSDT
# 47                                            MKRBUSD
# 48                                            MKRUSDT
# 49                                            MKRUSDT
# 50                                            MKRUSDT
# 51                                             MKRBNT
# 52                                             MKRUSD
# 53                                            MKRUSDC
# 54                                             MKRTHB
# 55                                            MKRUSDT
# 56                                             MKRBTC
# 57                                             MKRBTC
# 58                                             MKRBTC
# 59                                             MKRBTC
# 60                                            MKRUSDT
# 61                                             MKRETH
# 62                                             MKRBTC
# 63                                             MKRETH
# 64                                            MKRUSDT
# 65                                             MKRPHP
# 66                                             MKRBTC
# 67                                             MKRETH
# 68                                             MKRUSD
# 69                                             MKRDAI
# 70  0X050317D93F29D1BA5FF3EAC3B8157FD4E345588D0XA5...
# 71  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A20XC0...
# 72                                             MKREUR
# 73                                             MKRUSD
# 74                                            MKRUSDT
# 75                                            MKRUSDT
# 76                                            MKRUSDT
# 77                                            MKRUSDT
# 78                                            MKRUSDT
# 79                                            MKRUSDT
# 80                                            MKRUSDT
# 81                                            MKRBUSD
# 82                                             MKRETH
# 83                                             MKRETH
# 84                                             MKRUSD
# 85                                             MKRBTC
# 86                                             MKRBTC
# 87  0X9F8F72AA9304C8B593D555F12EF6589CC3A579A20XC0...
# 88                                             MKRBTC
# 89                                             MKRBTC
# 90                                             MKRBTC
# 91                                             MKRBTC
# 92                                             MKRGBP
# 93                                             MKRCAD
# 94                                            MKRUSDT
# 95                                            MKRUSDT
# 96                                            MKRUSDT
# 97      0X9F8F72AA9304C8B593D555F12EF6589CC3A579A2ETH
# 98                                            MKRUSDT
# 99                                             MKRBTC
#
#              market_and_volume  \
# 0            DigiFinex (563.0)
# 1                  EXMO (83.4)
# 2                Bibox (525.0)
# 3   Coinbase Exchange (3925.9)
# 4             Binance (4046.8)
# 5               Azbit (1030.2)
# 6              Bitget (1817.6)
# 7   Crypto.com Exchange (36.5)
# 8          MEXC Global (106.7)
# 9             WhiteBIT (107.3)
# 10              Bitvavo (85.9)
# 11            Deepcoin (208.0)
# 12              Kraken (130.8)
# 13              LBank (1571.0)
# 14             Binance (468.3)
# 15               Dcoin (975.0)
# 16               BingX (278.1)
# 17             XT.COM (1633.2)
# 18                 OKX (939.2)
# 19             Bitstamp (11.7)
# 20               Kraken (21.1)
# 21               Bibox (104.0)
# 22             Bitbank (125.9)
# 23              KuCoin (204.6)
# 24             Bitazza (136.2)
# 25              Gemini (128.2)
# 26             Rhino.fi (31.0)
# 27             Binance (144.7)
# 28              Phemex (789.1)
# 29           Cryptology (28.5)
# 30               Bitazza (9.8)
# 31             Bitfinex (79.7)
# 32           Binance US (88.5)
# 33           Binance US (17.3)
# 34              BitMart (93.5)
# 35              Hotbit (141.9)
# 36    Coinbase Exchange (23.0)
# 37               Huobi (746.1)
# 38               CoinEx (14.2)
# 39              Gate.io (66.6)
# 40              BitBNS (713.4)
# 41               XT.COM (58.1)
# 42              LATOKEN (91.7)
# 43              Bitfinex (8.5)
# 44                 OKX (110.5)
# 45             Sushiswap (6.3)
# 46                Bybit (44.6)
# 47              Bitrue (413.4)
# 48                BIT (1039.5)
# 49          BtcTurk PRO (33.0)
# 50           Coinstore (742.2)
# 51           Bancor (V2) (3.1)
# 52                Bitso (28.0)
# 53               CoinEx (10.5)
# 54               Bitkub (25.5)
# 55               Fameex (62.7)
# 56               CoinEx (10.8)
# 57                 OKX (107.9)
# 58                KuCoin (3.7)
# 59              LATOKEN (59.6)
# 60                 Kanga (0.0)
# 61               Gate.io (6.0)
# 62               Bittrex (0.2)
# 63                  OKX (10.3)
# 64        ProBit Global (90.8)
# 65              Coins.ph (0.4)
# 66         ProBit Global (9.1)
# 67                KuCoin (0.4)
# 68   Crypto.com Exchange (2.1)
# 69                EXMO (100.0)
# 70            Energiswap (0.1)
# 71        Uniswap (v3) (165.9)
# 72             Coinmetro (4.3)
# 73             Coinmetro (2.0)
# 74               Nominex (5.4)
# 75            CoinDCX (4045.9)
# 76            TokoCrypto (3.3)
# 77           WOO Network (4.0)
# 78            FMFW.io (1136.9)
# 79             HitBTC (1137.4)
# 80              Pionex (338.8)
# 81               Nominex (0.7)
# 82               FMFW.io (5.9)
# 83                HitBTC (5.9)
# 84                BTSE (746.0)
# 85               HitBTC (45.8)
# 86              FMFW.io (45.8)
# 87         Uniswap (v2) (16.8)
# 88             CoinDCX (143.7)
# 89                  P2B (18.3)
# 90               Nominex (0.0)
# 91                Pionex (2.9)
# 92                Kraken (2.6)
# 93                Bitbuy (0.1)
# 94              Coinzix (48.3)
# 95           ExMarkets (459.9)
# 96              Bilaxy (176.7)
# 97         Balancer (v2) (1.6)
# 98              Omgfin (251.3)
# 99              Omgfin (161.1)
#
#                                             Exchanges
# 0   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 1   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 2   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 3   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 4   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 5   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 6   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 7   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 8   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 9   DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 10  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 11  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 12  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 13  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 14  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 15  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 16  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 17  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 18  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 19  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 20  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 21  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 22  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 23  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 24  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 25  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 26  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 27  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 28  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 29  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 30  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 31  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 32  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 33  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 34  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 35  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 36  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 37  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 38  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 39  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 40  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 41  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 42  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 43  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 44  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 45  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 46  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 47  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 48  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 49  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 50  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 51  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 52  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 53  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 54  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 55  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 56  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 57  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 58  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 59  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 60  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 61  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 62  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 63  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 64  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 65  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 66  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 67  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 68  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 69  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 70  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 71  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 72  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 73  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 74  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 75  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 76  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 77  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 78  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 79  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 80  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 81  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 82  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 83  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 84  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 85  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 86  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 87  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 88  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 89  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 90  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 91  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 92  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 93  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 94  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 95  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 96  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 97  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 98  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...
# 99  DigiFinex (563.0), EXMO (83.4), Bibox (525.0),...

# %%
#@title Charts

 
import datetime
import time
import json
from google.colab import data_table
from pycoingecko import CoinGeckoAPI
import plotly.graph_objects as go
import pandas as pd
import matplotlib.pyplot as plt
from pytrends.request import TrendReq


cg = CoinGeckoAPI()

"""
1 - 2 days: 30 minutes
3 - 30 days: 4 hours
31 days and beyond: 4 days
"""
#chart  1
a = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 'max' )
df  = pd.DataFrame(data=a, columns = ['Date','Open','High', 'Low', 'Close'])
df['datetime'] = pd.to_datetime(df['Date'], unit='ms')
fig2 = go.Figure(data=[go.Candlestick(x=df['datetime'],open=df['Open'], high=df['High'],low=df['Low'], close=df['Close'])])                    
fig2.show()

#chart   2
b = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 180 )
df2  = pd.DataFrame(data=b, columns = ['Date','Open','High', 'Low', 'Close'])
df2['datetime'] = pd.to_datetime(df2['Date'], unit='ms')
fig3 = go.Figure(data=[go.Candlestick(x=df2['datetime'],open=df2['Open'], high=df2['High'],low=df2['Low'], close=df2['Close'])])                    
fig3.show()

#chart   3
b = cg.get_coin_ohlc_by_id(id=CoinGecko_id, vs_currency='usd', days = 30 )
df2  = pd.DataFrame(data=b, columns = ['Date','Open','High', 'Low', 'Close'])
df2['datetime'] = pd.to_datetime(df2['Date'], unit='ms')
fig3 = go.Figure(data=[go.Candlestick(x=df2['datetime'],open=df2['Open'], high=df2['High'],low=df2['Low'], close=df2['Close'])])                    
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a49a608d-1098-4cac-aac6-bf138c598146" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a49a608d-1098-4cac-aac6-bf138c598146")) {                    Plotly.newPlot(                        "a49a608d-1098-4cac-aac6-bf138c598146",                        [{"close":[1042.82,1148.86,1009.36,1152.97,1466.65,1301.32,1218.75,1560.43,1557.39,1404.89,1323.13,1155.28,895.17,1056.11,1098.04,1083.79,964.81,1023.76,1020.17,959.93,798.11,748.13,674.46,688.14,641.89,513.82,499.55,488.42,553.93,697.56,765.96,934.72,1012.85,1069.01,1053.5,1067.01,1063.97,952.55,906.76,861.58,776.19,738.53,779.85,800.09,680.2,619.7,539.15,522.87,484.45,501.67,561.48,548.37,552.96,547.97,638.77,596.84,632.52
93,714.14,702.47,711.67,711.78,704.75,698.69,666.26,650.91,639.03,649.39,652.31,655.57,661.39,664.74,668.67,667.2,659.33,665.54,684.23,713.05,718.7,723.18,723.35,716.82,710.9,718.37,704.51,712.86,716.48,731.04,735.87,722.74,724.27,718.62,718.6,718.03,709.02,708.78,711.55,713.07,711.16,702.66,713.16,714.49,663.02,663.78,663.2,660.31,655.91,672.14,672.35,674.68,671.79,670.13,658.5,658.92,658.21,654.22,654.55,654.64,659.39],"low":[525.77,514.25,517.19,520.69,518.23,523.3,520.58,513.13,518.08,516.32,513.69,511.31,513.83,519.33,522.61,521.0,522.41,525.65,518.66,509.44,506.48,504.86,503.94,507.63,509.01,510.8,507.49,509.3,514.4,511.89,512.97,511.1,508.71,510.18,512.27,512.01,507.03,504.58,504.44,514.81,514.63,513.69,515.74,513.77,518.74,527.85,523.32,523.52,522.53,527.02,525.18,517.36,519.51,518.94,525.99,534.4,539.66,540.21,540.45,539.29,538.83,550.53,547.25,553.17,566.7,565.61,561.47,572.98,592.44,606.89,617.58,636.4,635.32,618.64,615.46,619.24,621.71,622.79,612.68,630.69,631.29,624.02,620.08,617.6,610.59,616.7,637.59,634.29,631.93,624.35,634.45,647.77,646.91,654.54,652.2,645.76,648.37,654.75,689.75,701.48,704.67,707.35,697.59,701.55,691.02,687.36,676.27,681.06,697.38,699.84,700.84,707.26,691.32,683.91,686.09,687.71,680.9,683.96,691.95,696.22,705.06,698.38,696.07,703.41,683.82,685.51,643.62,643.9,636.24,645.05,646.93,646.78,654.77,660.48,6 ...

# %%
#@title Google Trends
pytrend = TrendReq()

# Create payload and capture API tokens. Only needed for interest_over_time(), interest_by_region() & related_queries()
keyword = str(CoinGecko_id)
keyword = keyword.replace('-',' ')
pytrend.build_payload(kw_list=[keyword])


interest_over_time_df = pytrend.interest_over_time()
df_Google=interest_over_time_df

#print(interest_over_time_df.tail(10))
# multiple line plot
# multiple line plot
plt.plot( keyword, 'y1', data=df_Google, marker='x', color='blue',linestyle='-', linewidth=1,ms=1.5 )

# %%
#@title  Project Recent Tweets
import configparser
import tweepy

config_file = "/content/drive/MyDrive/workspace/config.ini"
config_obj = configparser.ConfigParser()
config_obj.read(config_file)

Twitter = config_obj["Twitter_API"]

consumer_key = Twitter["consumer_key"]
consumer_secret = Twitter["consumer_secret"]
access_token = Twitter["access_token"]
access_token_secret = Twitter["access_token_secret"]

pd.set_option('display.width', 10)

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

user_name =str(json_parsed['links']['twitter_screen_name'])

def twitter_rept(user_name):
    """
    
    Generating text data of recent tweets

    """
    
    user =  api.user_timeline(screen_name = user_name )

    for tweet in user:
      
        print(tweet.created_at)

        print(tweet.text)

        print("------------------------------------------------------------------") 
        print(Twitters)

    return 
    
twitter_rept(user_name)
# Out:
# 2023-01-27 17:27:55+00:00
# D3M at its finest. https://t.co/xyGEkcKPUX
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 17:27:54+00:00
# 🌊🌊🌊 A new wave of fresh 15 million DAI is getting ready for a direct, automated, and algorithmic deposit into… https://t.co/1nm9sPv0Ut
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:08+00:00
# 🗳 It's your turn, MKR holders and delegates, to participate meaningfully in the direction of MakerDAO.
#
# Vote direct… https://t.co/qBV80WiQzU
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:07+00:00
# • Remove FLASH_Killer and remove it from the chainlog - FLASH_Killer was specific to MCD_FLASH_LEGACY which will be… https://t.co/zieC67cFf5
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:06+00:00
# ⚡️ Completing the Flash Mint Module Upgrade
#
# The following changes to the Flash Mint Module will be made if this ex… https://t.co/quZtmDqH3x
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:05+00:00
# Please see this post from Protocol Engineering Core Unit Facilitator Derek to inform your position on the AaveD3M c… https://t.co/n4Qj0899gT
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:04+00:00
# 🌊 Cage DIRECT-AAVEV2-DAI
#
# In preparation for a new Aave D3M deployment, if this executive proposal passes, it will… https://t.co/zJCuFh5cW1
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:03+00:00
# 💸 CES MKR Vesting Transfer
#
# The following transfer of MKR to the Collateral Engineering Services Core Unit will be… https://t.co/odeUduW9zQ
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:02+00:00
# 💸 GUSD PSM tout Reduction
#
# The following change to the GUSD Peg Stability Module (PSM) will be made, if this execut… https://t.co/Holj6URwEf
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:01+00:00
# • The DIRECT-COMPV2-DAI (Compound V2 D3M) Target Available Debt (gap) will be set to 5 million DAI.
#
# • The PSM-USDP… https://t.co/8RAshV3A4B
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:31:00+00:00
# • The WSTETH-B Stability Fee will be increased by 0.25% from 0% to 0.25%.
#
# • The DIRECT-COMPV2-DAI (Compound V2 D3M… https://t.co/A6dtzBuf4o
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:30:59+00:00
# 📊 MOMC Parameter Changes
#
# The following changes recommended by the Maker Open Market Committee (MOMC) will be made,… https://t.co/BgUkxzZqyr
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-27 14:30:58+00:00
# A new Executive Vote is live on the Maker Governance portal!
#
# 🗳 https://t.co/MQnJlHWSB3
#
# MKR holders and delegates… https://t.co/apgoMorXKi
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:09:04+00:00
# In order to be implemented in MakerDAO and the Maker Protocol, MIP100 must pass the MakerDAO governance cycle, wher… https://t.co/kWuaFlOglL
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:09:03+00:00
# MIP100 is a proposal with a Request for Comments (RFC) status — a community review period where attendant redraftin… https://t.co/UfFYyyoP9z
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:09:02+00:00
# This framework also would prohibit stable assets without favored status from exceeding 100,000,000 DAI within the M… https://t.co/djXO8MXanz
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:09:01+00:00
# • The assets must also remain within a Peg Stability Module (PSM) or in another location where Maker Governance can… https://t.co/1IpyC55IBp
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:09:00+00:00
# • Yield sharing must occur on all assets above 100,000,000 DAI within the Maker Protocol.
#
# • Yield must be paid out… https://t.co/TEgEAlb6g6
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:08:59+00:00
# As per the MIP100 proposed framework, in order to qualify as a "Favored Stable Asset", the asset must meet certain… https://t.co/T4XB81ZgtC
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO
# 2023-01-26 20:08:58+00:00
# The framework also aims to reduce the need for ad-hoc evaluations of individual stablecoin partnerships where the u… https://t.co/XUKngXhtlk
# ------------------------------------------------------------------
# Twitter: https://twitter.com/MakerDAO

# %%
#@title
t it
# Out:
#   File "<ipython-input-44-3d4b52f072d2>", line 2
#     t it
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Back test
